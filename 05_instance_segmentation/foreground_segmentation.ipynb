# %%
# %conda install -c conda-forge matplotlib 
# %conda install -c anaconda scipy
# !pip install tqdm h5py zarr pillow numpy imgaug==0.4.0 mahotas #imgaug has dependency on previous packages
# !pip install scikit-image
# !pip install tensorboard
# !pip install torchsummary
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.0
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/swolf/miniconda3/envs/exercise1
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> conda-forge::ca-certificates-2021.5.30-ha878542_0
#   certifi                anaconda::certifi-2020.6.20-py38_0 --> conda-forge::certifi-2021.5.30-py38h578d9bd_0
#   openssl               anaconda::openssl-1.1.1h-h7b6447c_0 --> pkgs/main::openssl-1.1.1l-h7f8727e_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/swolf/miniconda3/envs/exercise1
#
#   added / updated specs:
#     - scipy
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2021.5.3~ --> anaconda::ca-certificates-2020.10.14-0
#   certifi            conda-forge::certifi-2021.5.30-py38h5~ --> anaconda::certifi-2020.6.20-py38_0
#   openssl              pkgs/main::openssl-1.1.1l-h7f8727e_0 --> anaconda::openssl-1.1.1h-h7b6447c_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (4.62.2)
# Requirement already satisfied: h5py in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (3.4.0)
# Requirement already satisfied: zarr in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (2.9.5)
# Requirement already satisfied: pillow in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (8.3.2)
# Requirement already satisfied: numpy in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (1.21.2)
# Requirement already satisfied: imgaug==0.4.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: mahotas in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (1.4.11)
# Requirement already satisfied: imageio in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (2.9.0)
# Requirement already satisfied: opencv-python in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (4.5.3.56)
# Requirement already satisfied: matplotlib in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (3.4.3)
# Requirement already satisfied: six in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (1.16.0)
# Requirement already satisfied: scipy in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (1.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (0.18.3)
# Requirement already satisfied: Shapely in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from imgaug==0.4.0) (1.7.1)
# Requirement already satisfied: fasteners in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from zarr) (0.16.3)
# Requirement already satisfied: numcodecs>=0.6.4 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from zarr) (0.9.1)
# Requirement already satisfied: asciitree in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: networkx>=2.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (1.1.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2021.8.30)
# Requirement already satisfied: cycler>=0.10 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0) (2.8.2)
# Requirement already satisfied: scikit-image in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (0.18.3)
# Requirement already satisfied: networkx>=2.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (1.1.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (2021.8.30)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (8.3.2)
# Requirement already satisfied: scipy>=1.0.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (1.7.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (3.4.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from scikit-image) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: six in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.16.0)
# Requirement already satisfied: tensorboard in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (52.0.0.post20210125)
# Requirement already satisfied: protobuf>=3.6.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (3.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (1.40.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (2.0.1)
# Requirement already satisfied: wheel>=0.26 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (0.37.0)
# Requirement already satisfied: absl-py>=0.4 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (1.21.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from tensorboard) (2.26.0)
# Requirement already satisfied: six in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard) (1.16.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.1)
# Requirement already satisfied: torchsummary in /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages (1.5.1)

# %%
# %matplotlib inline
from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"


import torch
from __future__ import division, print_function
from torch.utils.data import Dataset
import glob
import os
import zarr
import random
import datetime
import numpy as np

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
# import h5py
# from imgaug import augmenters as iaa
# from imgaug.augmentables.segmaps import SegmentationMapsOnImage
# from imgaug.augmentables.heatmaps import HeatmapsOnImage
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchsummary import summary
from skimage import io
from colormap import *
from unet_fov import *

plt.rcParams['image.cmap'] = 'gist_earth'
torch.backends.cudnn.benchmark = True

# %%
# decompress data
from shutil import unpack_archive
unpack_archive('example_toy_data.zip', './')

# %%
def running_mean(x, n):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[n:] - cumsum[:-n]) / float(n)

def plot_history(history):
    # plot training and validation loss and binary accuracy
    
    loss = running_mean(history['loss'], 9)
    val_loss = running_mean(history['val_loss'], 9)
    #epochs = len(history.history['loss'])
    epochs = len(loss)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    ax1.plot(range(0, epochs), loss , label='loss')
    ax1.plot(range(0, epochs), val_loss, label='val_loss')
    ax1.set_title('train and validation loss')
    ax1.legend(loc='upper right')
    
    acc = running_mean(history['binary_accuracy'], 9)
    val_acc = running_mean(history['val_binary_accuracy'], 9)

    ax2.plot(range(0, epochs), acc, label='binary_accuracy')
    ax2.plot(range(0, epochs), val_acc, label='val_binary_accuracy')
    ax2.set_title('train and validation binary accuracy')
    ax2.legend(loc='lower right')

    plt.show()

# %%
def show_predictions(raw, gt, pred):
    
    thresh = 0.9
    max_values = np.max(pred[:,0], axis=(1, 2))
    if np.any(max_values < thresh):
        print("Heads up: If prediction is below {} then the prediction map is shown.".format(thresh))
        print("Max predictions: {}".format(max_values))
    
    num_samples = pred.shape[0]
    fig, ax = plt.subplots(num_samples, 3, sharex=True, sharey=True, figsize=(12, num_samples * 4))
    for i in range(num_samples):
        ax[i, 0].imshow(raw[i,0], aspect="auto")
        ax[i, 1].imshow(gt[i,0], aspect="auto")
        # check for prediction threshold
        if np.sum(max_values[i]) < thresh:
            ax[i, 2].imshow(pred[i,0], aspect="auto")
        else:
            ax[i, 2].imshow(pred[i,0] >= thresh, aspect="auto")

    ax[0, 0].set_title("Input")
    ax[0, 1].set_title("Ground truth")
    ax[0, 2].set_title("Prediction")
    fig.tight_layout()

# %% [markdown]
# ## (1) Load and visualize our toy data examples:
#
#
# we have 12 train samples, 3 validation samples and 3 test samples.

# %%
# load tif images and reformat it
def load_dataset(in_folder):
    x = []
    y = []
    raw_files = glob.glob(in_folder + '/raw_*.tif')
    for raw_file in raw_files:
        x.append(io.imread(raw_file)) 
        y.append(io.imread(raw_file.replace('raw', 'gt'))) 
    x = np.array(x)[:, np.newaxis] #shape [N, 1, H, W]
    y = np.array(y)[:, np.newaxis] #shape [N, 1, H, W]
    return x, y

# %%
# load data into train/val/test sets
x_train, y_train = load_dataset('example_toy_data/train')
x_val, y_val = load_dataset('example_toy_data/val')
x_test, y_test = load_dataset('example_toy_data/test')

batch_size = 4
# make dataloaders
train_loader = DataLoader(list(zip(x_train, y_train)), batch_size=batch_size, shuffle=True, pin_memory=True)
val_loader = DataLoader(list(zip(x_val, y_val)), batch_size=1, pin_memory=True)
test_loader = DataLoader(list(zip(x_test, y_test)), batch_size=1)

# %%
# show training examples
num_samples = 3
fig, ax = plt.subplots(num_samples, 2, sharey=True, figsize=(8, num_samples * 4))
for i in range(num_samples):
    ax[i, 0].imshow(x_train[i,0], aspect="auto")
    ax[i, 1].imshow(y_train[i,0], aspect="auto")
ax[0, 0].set_title("Input")
ax[0, 1].set_title("Ground truth")
fig.tight_layout()

# %% [markdown]
# ## (2) Create and train our model

# %%
# set seed
torch.manual_seed(42)

# define model
out_channels = 1
d_factors = [[2,2],[2,2],[2,2],[2,2]]
activation = torch.nn.Sigmoid()

net = torch.nn.Sequential(
    UNet(in_channels=1,
    num_fmaps=6,
    fmap_inc_factors=2,
    downsample_factors=d_factors,
    activation='ReLU',
    padding='same',
    num_fmaps_out=6,
    constant_upsample=False
    ),
    torch.nn.Conv2d(in_channels=6, out_channels=out_channels, kernel_size=1, padding=0, bias=True))

receptive_field, _ = net[0].get_fov()

# print network layers
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = net.to(device)
summary(net, (1,512,512))
print("Receptive field: ", receptive_field)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 6, 512, 512]              60
#               ReLU-2          [-1, 6, 512, 512]               0
#             Conv2d-3          [-1, 6, 512, 512]             330
#               ReLU-4          [-1, 6, 512, 512]               0
#           ConvPass-5          [-1, 6, 512, 512]               0
#          MaxPool2d-6          [-1, 6, 256, 256]               0
#         Downsample-7          [-1, 6, 256, 256]               0
#             Conv2d-8         [-1, 12, 256, 256]             660
#               ReLU-9         [-1, 12, 256, 256]               0
#            Conv2d-10         [-1, 12, 256, 256]           1,308
#              ReLU-11         [-1, 12, 256, 256]               0
#          ConvPass-12         [-1, 12, 256, 256]               0
#         MaxPool2d-13         [-1, 12, 128, 128]               0
#        Downsample-14         [-1, 12, 128, 128]               0
#            Conv2d-15         [-1, 24, 128, 128]           2,616
#              ReLU-16         [-1, 24, 128, 128]               0
#            Conv2d-17         [-1, 24, 128, 128]           5,208
#              ReLU-18         [-1, 24, 128, 128]               0
#          ConvPass-19         [-1, 24, 128, 128]               0
#         MaxPool2d-20           [-1, 24, 64, 64]               0
#        Downsample-21           [-1, 24, 64, 64]               0
#            Conv2d-22           [-1, 48, 64, 64]          10,416
#              ReLU-23           [-1, 48, 64, 64]               0
#            Conv2d-24           [-1, 48, 64, 64]          20,784
#              ReLU-25           [-1, 48, 64, 64]               0
#          ConvPass-26           [-1, 48, 64, 64]               0
#         MaxPool2d-27           [-1, 48, 32, 32]               0
#        Downsample-28           [-1, 48, 32, 32]               0
#            Conv2d-29           [-1, 96, 32, 32]          41,568
#              ReLU-30           [-1, 96, 32, 32]               0
#            Conv2d-31           [-1, 96, 32, 32]          83,040
#              ReLU-32           [-1, 96, 32, 32]               0
#          ConvPass-33           [-1, 96, 32, 32]               0
#   ConvTranspose2d-34           [-1, 96, 64, 64]          36,960
#          Upsample-35          [-1, 144, 64, 64]               0
#            Conv2d-36           [-1, 48, 64, 64]          62,256
#              ReLU-37           [-1, 48, 64, 64]               0
#            Conv2d-38           [-1, 48, 64, 64]          20,784
#              ReLU-39           [-1, 48, 64, 64]               0
#          ConvPass-40           [-1, 48, 64, 64]               0
#   ConvTranspose2d-41         [-1, 48, 128, 128]           9,264
#          Upsample-42         [-1, 72, 128, 128]               0
#            Conv2d-43         [-1, 24, 128, 128]          15,576
#              ReLU-44         [-1, 24, 128, 128]               0
#            Conv2d-45         [-1, 24, 128, 128]           5,208
#              ReLU-46         [-1, 24, 128, 128]               0
#          ConvPass-47         [-1, 24, 128, 128]               0
#   ConvTranspose2d-48         [-1, 24, 256, 256]           2,328
#          Upsample-49         [-1, 36, 256, 256]               0
#            Conv2d-50         [-1, 12, 256, 256]           3,900
#              ReLU-51         [-1, 12, 256, 256]               0
#            Conv2d-52         [-1, 12, 256, 256]           1,308
#              ReLU-53         [-1, 12, 256, 256]               0
#          ConvPass-54         [-1, 12, 256, 256]               0
#   ConvTranspose2d-55         [-1, 12, 512, 512]             588
#          Upsample-56         [-1, 18, 512, 512]               0
#            Conv2d-57          [-1, 6, 512, 512]             978
#              ReLU-58          [-1, 6, 512, 512]               0
#            Conv2d-59          [-1, 6, 512, 512]             330
#              ReLU-60          [-1, 6, 512, 512]               0
#          ConvPass-61          [-1, 6, 512, 512]               0
#              UNet-62          [-1, 6, 512, 512]               0
#            Conv2d-63          [-1, 1, 512, 512]               7
# ================================================================
# Total params: 325,477
# Trainable params: 325,477
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 366.50
# Params size (MB): 1.24
# Estimated Total Size (MB): 368.74
# ----------------------------------------------------------------
# Receptive field:  200
# /home/swolf/miniconda3/envs/exercise1/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# ### Receptive Field of View
#
# The number of convolutions and the depth of the U-Net are the major factors in determining the
# receptive field of the network. The term is borrowed from biology where it describes the "portion of sensory space that can elicit neuronal responses when stimulated" (wikipedia). Each output pixel can look at/depends on an input patch with that diameter centered at its position.
# Based on this patch, the network has to be able to make a decision about the prediction for the respective pixel.
# Yet larger sizes increase the computation time significantly.
#
# The following code snippet visualizes the field of view of the center pixel for networks with varying depth:

# %%
rnd = random.randrange(len(x_train))
image = x_train[rnd]
label = y_train[rnd]


net_t = image
fovs = []
d_factors = [[2,2],[2,2],[2,2],[2,2]]

for level in range(len(d_factors)):
    fov_tmp, _ = net[0].rec_fov(level , (1, 1), 1)
    fovs.append(fov_tmp[0])

image = np.squeeze(image)
fig=plt.figure(figsize=(8, 8))
colors = ["yellow", "red", "green", "blue", "magenta"]
plt.imshow(image, cmap='gray')
for idx, fov_t in enumerate(fovs):
    print("Field of view at depth {}: {:3d} (color: {})".format(idx+1, fov_t, colors[idx]))
    xmin = image.shape[1]/2 - fov_t/2
    xmax = image.shape[1]/2 + fov_t/2
    ymin = image.shape[1]/2 - fov_t/2
    ymax = image.shape[1]/2 + fov_t/2
    plt.hlines(ymin, xmin, xmax, color=colors[idx], lw=3)
    plt.hlines(ymax, xmin, xmax, color=colors[idx], lw=3)
    plt.vlines(xmin, ymin, ymax, color=colors[idx], lw=3)
    plt.vlines(xmax, ymin, ymax, color=colors[idx], lw=3)
plt.show()
# Out:
# Field of view at depth 1:   5 (color: yellow)
# Field of view at depth 2:  18 (color: red)
# Field of view at depth 3:  44 (color: green)
# Field of view at depth 4:  96 (color: blue)

# %%
dtype = torch.FloatTensor
def training_step(model, loss_fn, optimizer, feature, label):
    # speedup version of setting gradients to zero
    for param in model.parameters():
        param.grad = None
    # forward
    logits = model(feature) # B x C x H x W
    loss_value = loss_fn(input=logits, target=label) # label.squeeze(0) for three_class
    # backward if training mode
    if net.training:
        loss_value.backward()
        optimizer.step()
    if activation is not None:
        output = activation(logits)
    else:
        output = logits
    outputs = {
        'pred': output,
        'logits': logits,
    }
    return loss_value, outputs

def calc_accuracy(y_pred, y_true):
    y_pred=torch.ge(y_pred, 0.5)
   # y_pred = torch.round(y_pred)
    return y_pred.eq(y_true).float().mean()
                
def train(net, epochs, learning_rate,start_epoch=0, optimizer=None, history=None, early_stopping=None,img_gen=None):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    loss_fn = torch.nn.BCEWithLogitsLoss()
    loss_fn = loss_fn.to(device)
    # set optimizer
    if optimizer is None:
        optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate) 
    if history is None:
        history = {'loss':[],
                  'val_loss':[],
                  'binary_accuracy':[],
                  'val_binary_accuracy':[]}
    if img_gen:
        pbar = tqdm(total=epochs)
    else:
        pbar = tqdm(total=epochs*len(train_loader))
    for epoch in range(0, epochs):
    #for epoch in tqdm(range(0, epochs)):
        
        if img_gen:
            net.train()
            train_acc_loss = []
            train_acc_accuracy = []
            feature,label=next(img_gen)
            label = label.type(dtype)
            label = label.to(device)
            feature = feature.to(device)
            loss_value, outputs = training_step(net, loss_fn, optimizer, feature, label)
            pbar.update(1)
            train_acc_loss.append(loss_value.cpu().detach().numpy())
            accuracy = calc_accuracy(outputs['pred'], label)
            train_acc_accuracy.append(float(accuracy.cpu().detach().numpy()))
        else:
            # reset data loader to get random augmentations
            np.random.seed()
            tmp_loader = iter(train_loader)
            train_acc_loss = []
            train_acc_accuracy = []
            net.train()
            for feature, label in tmp_loader:
                label = label.type(dtype)
                label = label.to(device)
                feature = feature.to(device)
                loss_value, outputs = training_step(net, loss_fn, optimizer, feature, label)
                pbar.update(1)
                train_acc_loss.append(loss_value.cpu().detach().numpy())
                accuracy = calc_accuracy(outputs['pred'], label)
                train_acc_accuracy.append(float(accuracy.cpu().detach().numpy()))
        history['loss'].append(np.mean(train_acc_loss))
        history['binary_accuracy'].append(np.mean(train_acc_accuracy))
        # validation
        net.eval()
        tmp_val_loader = iter(val_loader)
        val_acc_loss = []
        val_acc_accuracy = []
        for feature, label in tmp_val_loader:                    
            label = label.type(dtype)
            label = label.to(device)
            feature = feature.to(device)
            loss_value, outputs = training_step(net, loss_fn, optimizer, feature, label)
            val_acc_loss.append(loss_value.cpu().detach().numpy())
            accuracy = calc_accuracy(outputs['pred'], label)
            val_acc_accuracy.append(float(accuracy.cpu().detach().numpy()))
        history['val_loss'].append(np.mean(val_acc_loss))
        history['val_binary_accuracy'].append(np.mean(val_acc_accuracy))
        if early_stopping:
            #early_stopping(np.mean(acc_loss))
            early_stopping(np.mean(val_acc_loss))
            if early_stopping.early_stop:
                print('Early stopping after epoch', epoch)
                break
        print(f'Epoch {epoch+start_epoch+1}, train-loss: {np.mean(train_acc_loss):.4f} - train_accuracy:{np.mean(train_acc_accuracy):.4f}'+
      f' - val_loss:{np.mean(val_acc_loss):.4f} -val_accuracy:{np.mean(val_acc_accuracy):.4f}')
    return net, history, optimizer

# %%
num_epochs1 = 250
net, history, optimizer = train(net, num_epochs1, learning_rate=5e-4,start_epoch=0)
# Out:
#   0%|          | 0/750 [00:00<?, ?it/s]
# Epoch 1, train-loss: 0.6425 - train_accuracy:0.9295 - val_loss:0.6399 -val_accuracy:0.9294
# Epoch 2, train-loss: 0.6386 - train_accuracy:0.9295 - val_loss:0.6360 -val_accuracy:0.9294
# Epoch 3, train-loss: 0.6345 - train_accuracy:0.9295 - val_loss:0.6321 -val_accuracy:0.9294
# Epoch 4, train-loss: 0.6309 - train_accuracy:0.9295 - val_loss:0.6291 -val_accuracy:0.9294
# Epoch 5, train-loss: 0.6285 - train_accuracy:0.9295 - val_loss:0.6271 -val_accuracy:0.9294
# Epoch 6, train-loss: 0.6264 - train_accuracy:0.9295 - val_loss:0.6251 -val_accuracy:0.9294
# Epoch 7, train-loss: 0.6244 - train_accuracy:0.9295 - val_loss:0.6230 -val_accuracy:0.9294
# Epoch 8, train-loss: 0.6222 - train_accuracy:0.9295 - val_loss:0.6207 -val_accuracy:0.9294
# Epoch 9, train-loss: 0.6199 - train_accuracy:0.9295 - val_loss:0.6182 -val_accuracy:0.9294
# Epoch 10, train-loss: 0.6172 - train_accuracy:0.9295 - val_loss:0.6153 -val_accuracy:0.9294
# Epoch 11, train-loss: 0.6141 - train_accuracy:0.9295 - val_loss:0.6118 -val_accuracy:0.9294
# Epoch 12, train-loss: 0.6103 - train_accuracy:0.9295 - val_loss:0.6073 -val_accuracy:0.9294
# Epoch 13, train-loss: 0.6054 - train_accuracy:0.9295 - val_loss:0.6017 -val_accuracy:0.9294
# Epoch 14, train-loss: 0.5995 - train_accuracy:0.9295 - val_loss:0.5963 -val_accuracy:0.9294
# Epoch 15, train-loss: 0.5951 - train_accuracy:0.9295 - val_loss:0.5929 -val_accuracy:0.9294
# Epoch 16, train-loss: 0.5916 - train_accuracy:0.9295 - val_loss:0.5891 -val_accuracy:0.9294
# Epoch 17, train-loss: 0.5877 - train_accuracy:0.9295 - val_loss:0.5847 -val_accuracy:0.9294
# Epoch 18, train-loss: 0.5830 - train_accuracy:0.9295 - val_loss:0.5794 -val_accuracy:0.9294
# Epoch 19, train-loss: 0.5776 - train_accuracy:0.9295 - val_loss:0.5732 -val_accuracy:0.9294
# Epoch 20, train-loss: 0.5710 - train_accuracy:0.9295 - val_loss:0.5656 -val_accuracy:0.9294
# Epoch 21, train-loss: 0.5629 - train_accuracy:0.9295 - val_loss:0.5560 -val_accuracy:0.9294
# Epoch 22, train-loss: 0.5524 - train_accuracy:0.9295 - val_loss:0.5430 -val_accuracy:0.9294
# Epoch 23, train-loss: 0.5376 - train_accuracy:0.9295 - val_loss:0.5224 -val_accuracy:0.9294
# Epoch 24, train-loss: 0.5114 - train_accuracy:0.9295 - val_loss:0.4748 -val_accuracy:0.9294
# Epoch 25, train-loss: 0.4292 - train_accuracy:0.9295 - val_loss:0.2939 -val_accuracy:0.9294
# Epoch 26, train-loss: 0.3451 - train_accuracy:0.9295 - val_loss:0.2909 -val_accuracy:0.9294
# Epoch 27, train-loss: 0.3007 - train_accuracy:0.9295 - val_loss:0.3219 -val_accuracy:0.9294
# Epoch 28, train-loss: 0.3205 - train_accuracy:0.9295 - val_loss:0.2987 -val_accuracy:0.9294
# Epoch 29, train-loss: 0.2910 - train_accuracy:0.9295 - val_loss:0.2951 -val_accuracy:0.9294
# Epoch 30, train-loss: 0.2963 - train_accuracy:0.9295 - val_loss:0.2824 -val_accuracy:0.9294
# Epoch 31, train-loss: 0.2832 - train_accuracy:0.9295 - val_loss:0.2847 -val_accuracy:0.9294
# Epoch 32, train-loss: 0.2854 - train_accuracy:0.9295 - val_loss:0.2799 -val_accuracy:0.9294
# Epoch 33, train-loss: 0.2783 - train_accuracy:0.9295 - val_loss:0.2769 -val_accuracy:0.9294
# Epoch 34, train-loss: 0.2781 - train_accuracy:0.9295 - val_loss:0.2749 -val_accuracy:0.9294
# Epoch 35, train-loss: 0.2736 - train_accuracy:0.9295 - val_loss:0.2721 -val_accuracy:0.9294
# Epoch 36, train-loss: 0.2723 - train_accuracy:0.9295 - val_loss:0.2702 -val_accuracy:0.9294
# Epoch 37, train-loss: 0.2697 - train_accuracy:0.9295 - val_loss:0.2688 -val_accuracy:0.9294
# Epoch 38, train-loss: 0.2677 - train_accuracy:0.9295 - val_loss:0.2656 -val_accuracy:0.9294
# Epoch 39, train-loss: 0.2649 - train_accuracy:0.9295 - val_loss:0.2636 -val_accuracy:0.9294
# Epoch 40, train-loss: 0.2623 - train_accuracy:0.9295 - val_loss:0.2604 -val_accuracy:0.9294
# Epoch 41, train-loss: 0.2584 - train_accuracy:0.9295 - val_loss:0.2562 -val_accuracy:0.9294
# Epoch 42, train-loss: 0.2533 - train_accuracy:0.9295 - val_loss:0.2509 -val_accuracy:0.9294
# Epoch 43, train-loss: 0.2471 - train_accuracy:0.9295 - val_loss:0.2439 -val_accuracy:0.9294
# Epoch 44, train-loss: 0.2386 - train_accuracy:0.9295 - val_loss:0.2373 -val_accuracy:0.9294
# Epoch 45, train-loss: 0.2309 - train_accuracy:0.9295 - val_loss:0.2277 -val_accuracy:0.9294
# Epoch 46, train-loss: 0.2198 - train_accuracy:0.9295 - val_loss:0.2164 -val_accuracy:0.9294
# Epoch 47, train-loss: 0.2116 - train_accuracy:0.9295 - val_loss:0.2412 -val_accuracy:0.9294
# Epoch 48, train-loss: 0.2125 - train_accuracy:0.9295 - val_loss:0.2068 -val_accuracy:0.9294
# Epoch 49, train-loss: 0.1937 - train_accuracy:0.9295 - val_loss:0.1927 -val_accuracy:0.9294
# Epoch 50, train-loss: 0.1839 - train_accuracy:0.9295 - val_loss:0.1849 -val_accuracy:0.9294
# Epoch 51, train-loss: 0.1804 - train_accuracy:0.9295 - val_loss:0.1782 -val_accuracy:0.9294
# Epoch 52, train-loss: 0.2121 - train_accuracy:0.9295 - val_loss:0.2568 -val_accuracy:0.9294
# Epoch 53, train-loss: 0.2311 - train_accuracy:0.9295 - val_loss:0.2507 -val_accuracy:0.9294
# Epoch 54, train-loss: 0.2039 - train_accuracy:0.9295 - val_loss:0.2284 -val_accuracy:0.9294
# Epoch 55, train-loss: 0.2003 - train_accuracy:0.9295 - val_loss:0.2177 -val_accuracy:0.9294
# Epoch 56, train-loss: 0.2068 - train_accuracy:0.9295 - val_loss:0.1956 -val_accuracy:0.9294
# Epoch 57, train-loss: 0.1904 - train_accuracy:0.9295 - val_loss:0.2011 -val_accuracy:0.9294
# Epoch 58, train-loss: 0.1843 - train_accuracy:0.9295 - val_loss:0.1993 -val_accuracy:0.9294
# Epoch 59, train-loss: 0.1791 - train_accuracy:0.9295 - val_loss:0.1760 -val_accuracy:0.9294
# Epoch 60, train-loss: 0.1719 - train_accuracy:0.9295 - val_loss:0.1691 -val_accuracy:0.9294
# Epoch 61, train-loss: 0.1613 - train_accuracy:0.9295 - val_loss:0.1599 -val_accuracy:0.9294
# Epoch 62, train-loss: 0.1556 - train_accuracy:0.9295 - val_loss:0.1874 -val_accuracy:0.9294
# Epoch 63, train-loss: 0.1536 - train_accuracy:0.9295 - val_loss:0.1682 -val_accuracy:0.9294
# Epoch 64, train-loss: 0.1782 - train_accuracy:0.9295 - val_loss:0.1626 -val_accuracy:0.9294
# Epoch 65, train-loss: 0.1803 - train_accuracy:0.9295 - val_loss:0.2289 -val_accuracy:0.9294
# Epoch 66, train-loss: 0.1533 - train_accuracy:0.9295 - val_loss:0.1500 -val_accuracy:0.9294
# Epoch 67, train-loss: 0.1477 - train_accuracy:0.9295 - val_loss:0.1663 -val_accuracy:0.9294
# Epoch 68, train-loss: 0.1414 - train_accuracy:0.9295 - val_loss:0.1446 -val_accuracy:0.9294
# Epoch 69, train-loss: 0.1379 - train_accuracy:0.9295 - val_loss:0.1502 -val_accuracy:0.9294
# Epoch 70, train-loss: 0.1326 - train_accuracy:0.9295 - val_loss:0.1366 -val_accuracy:0.9294
# Epoch 71, train-loss: 0.1321 - train_accuracy:0.9295 - val_loss:0.1324 -val_accuracy:0.9294
# Epoch 72, train-loss: 0.1323 - train_accuracy:0.9295 - val_loss:0.2017 -val_accuracy:0.9294
# Epoch 73, train-loss: 0.1465 - train_accuracy:0.9295 - val_loss:0.1461 -val_accuracy:0.9294
# Epoch 74, train-loss: 0.1553 - train_accuracy:0.9295 - val_loss:0.1899 -val_accuracy:0.9294
# Epoch 75, train-loss: 0.1567 - train_accuracy:0.9295 - val_loss:0.2623 -val_accuracy:0.9294
# Epoch 76, train-loss: 0.1532 - train_accuracy:0.9295 - val_loss:0.1544 -val_accuracy:0.9294
# Epoch 77, train-loss: 0.1431 - train_accuracy:0.9295 - val_loss:0.1614 -val_accuracy:0.9294
# Epoch 78, train-loss: 0.1353 - train_accuracy:0.9295 - val_loss:0.1304 -val_accuracy:0.9294
# Epoch 79, train-loss: 0.1271 - train_accuracy:0.9295 - val_loss:0.1339 -val_accuracy:0.9294
# Epoch 80, train-loss: 0.1228 - train_accuracy:0.9295 - val_loss:0.1293 -val_accuracy:0.9294
# Epoch 81, train-loss: 0.1214 - train_accuracy:0.9295 - val_loss:0.1276 -val_accuracy:0.9294
# Epoch 82, train-loss: 0.1166 - train_accuracy:0.9295 - val_loss:0.1234 -val_accuracy:0.9294
# Epoch 83, train-loss: 0.1130 - train_accuracy:0.9295 - val_loss:0.1314 -val_accuracy:0.9294
# Epoch 84, train-loss: 0.1116 - train_accuracy:0.9295 - val_loss:0.1187 -val_accuracy:0.9294
# Epoch 85, train-loss: 0.1256 - train_accuracy:0.9295 - val_loss:0.1336 -val_accuracy:0.9294
# Epoch 86, train-loss: 0.1179 - train_accuracy:0.9295 - val_loss:0.1247 -val_accuracy:0.9294
# Epoch 87, train-loss: 0.1112 - train_accuracy:0.9295 - val_loss:0.1154 -val_accuracy:0.9294
# Epoch 88, train-loss: 0.1096 - train_accuracy:0.9295 - val_loss:0.1269 -val_accuracy:0.9294
# Epoch 89, train-loss: 0.1090 - train_accuracy:0.9295 - val_loss:0.1106 -val_accuracy:0.9294
# Epoch 90, train-loss: 0.1092 - train_accuracy:0.9295 - val_loss:0.1640 -val_accuracy:0.9294
# Epoch 91, train-loss: 0.1117 - train_accuracy:0.9295 - val_loss:0.1036 -val_accuracy:0.9294
# Epoch 92, train-loss: 0.1042 - train_accuracy:0.9299 - val_loss:0.1211 -val_accuracy:0.9390
# Epoch 93, train-loss: 0.0998 - train_accuracy:0.9484 - val_loss:0.0995 -val_accuracy:0.9699
# Epoch 94, train-loss: 0.0934 - train_accuracy:0.9673 - val_loss:0.0803 -val_accuracy:0.9738
# Epoch 95, train-loss: 0.0987 - train_accuracy:0.9689 - val_loss:0.0825 -val_accuracy:0.9684
# Epoch 96, train-loss: 0.0762 - train_accuracy:0.9737 - val_loss:0.1761 -val_accuracy:0.9409
# Epoch 97, train-loss: 0.0845 - train_accuracy:0.9724 - val_loss:0.0794 -val_accuracy:0.9738
# Epoch 98, train-loss: 0.0722 - train_accuracy:0.9747 - val_loss:0.1389 -val_accuracy:0.9534
# Epoch 99, train-loss: 0.0759 - train_accuracy:0.9742 - val_loss:0.0727 -val_accuracy:0.9742
# Epoch 100, train-loss: 0.0867 - train_accuracy:0.9715 - val_loss:0.0730 -val_accuracy:0.9737
# Epoch 101, train-loss: 0.0819 - train_accuracy:0.9724 - val_loss:0.0846 -val_accuracy:0.9725
# Epoch 102, train-loss: 0.0766 - train_accuracy:0.9756 - val_loss:0.0742 -val_accuracy:0.9755
# Epoch 103, train-loss: 0.0842 - train_accuracy:0.9714 - val_loss:0.0730 -val_accuracy:0.9746
# Epoch 104, train-loss: 0.0764 - train_accuracy:0.9737 - val_loss:0.0765 -val_accuracy:0.9734
# Epoch 105, train-loss: 0.0808 - train_accuracy:0.9730 - val_loss:0.0699 -val_accuracy:0.9759
# Epoch 106, train-loss: 0.0720 - train_accuracy:0.9753 - val_loss:0.1005 -val_accuracy:0.9683
# Epoch 107, train-loss: 0.0741 - train_accuracy:0.9744 - val_loss:0.0688 -val_accuracy:0.9762
# Epoch 108, train-loss: 0.0673 - train_accuracy:0.9767 - val_loss:0.0994 -val_accuracy:0.9672
# Epoch 109, train-loss: 0.0662 - train_accuracy:0.9767 - val_loss:0.0667 -val_accuracy:0.9770
# Epoch 110, train-loss: 0.0686 - train_accuracy:0.9761 - val_loss:0.0894 -val_accuracy:0.9726
# Epoch 111, train-loss: 0.0642 - train_accuracy:0.9779 - val_loss:0.0735 -val_accuracy:0.9758
# Epoch 112, train-loss: 0.0632 - train_accuracy:0.9781 - val_loss:0.0728 -val_accuracy:0.9762
# Epoch 113, train-loss: 0.0610 - train_accuracy:0.9788 - val_loss:0.0795 -val_accuracy:0.9756
# Epoch 114, train-loss: 0.0610 - train_accuracy:0.9788 - val_loss:0.0745 -val_accuracy:0.9761
# Epoch 115, train-loss: 0.0594 - train_accuracy:0.9791 - val_loss:0.0734 -val_accuracy:0.9771
# Epoch 116, train-loss: 0.0615 - train_accuracy:0.9789 - val_loss:0.0797 -val_accuracy:0.9770
# Epoch 117, train-loss: 0.0608 - train_accuracy:0.9789 - val_loss:0.0607 -val_accuracy:0.9786
# Epoch 118, train-loss: 0.0627 - train_accuracy:0.9780 - val_loss:0.0868 -val_accuracy:0.9758
# Epoch 119, train-loss: 0.0647 - train_accuracy:0.9782 - val_loss:0.0631 -val_accuracy:0.9776
# Epoch 120, train-loss: 0.0638 - train_accuracy:0.9777 - val_loss:0.0894 -val_accuracy:0.9758
# Epoch 121, train-loss: 0.0587 - train_accuracy:0.9791 - val_loss:0.0610 -val_accuracy:0.9790
# Epoch 122, train-loss: 0.0583 - train_accuracy:0.9794 - val_loss:0.0850 -val_accuracy:0.9775
# Epoch 123, train-loss: 0.0599 - train_accuracy:0.9787 - val_loss:0.0620 -val_accuracy:0.9790
# Epoch 124, train-loss: 0.0569 - train_accuracy:0.9798 - val_loss:0.0992 -val_accuracy:0.9743
# Epoch 125, train-loss: 0.0598 - train_accuracy:0.9783 - val_loss:0.0649 -val_accuracy:0.9770
# Epoch 126, train-loss: 0.0589 - train_accuracy:0.9784 - val_loss:0.1016 -val_accuracy:0.9767
# Epoch 127, train-loss: 0.0630 - train_accuracy:0.9780 - val_loss:0.0594 -val_accuracy:0.9794
# Epoch 128, train-loss: 0.0573 - train_accuracy:0.9797 - val_loss:0.1067 -val_accuracy:0.9787
# Epoch 129, train-loss: 0.0571 - train_accuracy:0.9797 - val_loss:0.0582 -val_accuracy:0.9803
# Epoch 130, train-loss: 0.0559 - train_accuracy:0.9806 - val_loss:0.0765 -val_accuracy:0.9799
# Epoch 131, train-loss: 0.0572 - train_accuracy:0.9808 - val_loss:0.0585 -val_accuracy:0.9796
# Epoch 132, train-loss: 0.0578 - train_accuracy:0.9801 - val_loss:0.0621 -val_accuracy:0.9801
# Epoch 133, train-loss: 0.0567 - train_accuracy:0.9804 - val_loss:0.0645 -val_accuracy:0.9791
# Epoch 134, train-loss: 0.0518 - train_accuracy:0.9815 - val_loss:0.0745 -val_accuracy:0.9800
# Epoch 135, train-loss: 0.0556 - train_accuracy:0.9801 - val_loss:0.0610 -val_accuracy:0.9787
# Epoch 136, train-loss: 0.0553 - train_accuracy:0.9810 - val_loss:0.0648 -val_accuracy:0.9807
# Epoch 137, train-loss: 0.0549 - train_accuracy:0.9810 - val_loss:0.0555 -val_accuracy:0.9818
# Epoch 138, train-loss: 0.0525 - train_accuracy:0.9819 - val_loss:0.0601 -val_accuracy:0.9798
# Epoch 139, train-loss: 0.0541 - train_accuracy:0.9812 - val_loss:0.0756 -val_accuracy:0.9808
# Epoch 140, train-loss: 0.0512 - train_accuracy:0.9820 - val_loss:0.0537 -val_accuracy:0.9812
# Epoch 141, train-loss: 0.0519 - train_accuracy:0.9812 - val_loss:0.0702 -val_accuracy:0.9799
# Epoch 142, train-loss: 0.0544 - train_accuracy:0.9798 - val_loss:0.0584 -val_accuracy:0.9812
# Epoch 143, train-loss: 0.0545 - train_accuracy:0.9802 - val_loss:0.0535 -val_accuracy:0.9815
# Epoch 144, train-loss: 0.0525 - train_accuracy:0.9811 - val_loss:0.0744 -val_accuracy:0.9798
# Epoch 145, train-loss: 0.0512 - train_accuracy:0.9820 - val_loss:0.0563 -val_accuracy:0.9827
# Epoch 146, train-loss: 0.0495 - train_accuracy:0.9824 - val_loss:0.0755 -val_accuracy:0.9801
# Epoch 147, train-loss: 0.0480 - train_accuracy:0.9835 - val_loss:0.0573 -val_accuracy:0.9834
# Epoch 148, train-loss: 0.0466 - train_accuracy:0.9839 - val_loss:0.0621 -val_accuracy:0.9823
# Epoch 149, train-loss: 0.0474 - train_accuracy:0.9841 - val_loss:0.0774 -val_accuracy:0.9816
# Epoch 150, train-loss: 0.0458 - train_accuracy:0.9844 - val_loss:0.0504 -val_accuracy:0.9841
# Epoch 151, train-loss: 0.0462 - train_accuracy:0.9844 - val_loss:0.0788 -val_accuracy:0.9822
# Epoch 152, train-loss: 0.0511 - train_accuracy:0.9837 - val_loss:0.0449 -val_accuracy:0.9838
# Epoch 153, train-loss: 0.0516 - train_accuracy:0.9832 - val_loss:0.0601 -val_accuracy:0.9832
# Epoch 154, train-loss: 0.0476 - train_accuracy:0.9827 - val_loss:0.0559 -val_accuracy:0.9828
# Epoch 155, train-loss: 0.0451 - train_accuracy:0.9842 - val_loss:0.0485 -val_accuracy:0.9845
# Epoch 156, train-loss: 0.0440 - train_accuracy:0.9846 - val_loss:0.0567 -val_accuracy:0.9825
# Epoch 157, train-loss: 0.0463 - train_accuracy:0.9846 - val_loss:0.0530 -val_accuracy:0.9858
# Epoch 158, train-loss: 0.0421 - train_accuracy:0.9854 - val_loss:0.0448 -val_accuracy:0.9859
# Epoch 159, train-loss: 0.0427 - train_accuracy:0.9853 - val_loss:0.0648 -val_accuracy:0.9848
# Epoch 160, train-loss: 0.0435 - train_accuracy:0.9851 - val_loss:0.0622 -val_accuracy:0.9854
# Epoch 161, train-loss: 0.0429 - train_accuracy:0.9854 - val_loss:0.0468 -val_accuracy:0.9860
# Epoch 162, train-loss: 0.0423 - train_accuracy:0.9858 - val_loss:0.0783 -val_accuracy:0.9849
# Epoch 163, train-loss: 0.0456 - train_accuracy:0.9856 - val_loss:0.0440 -val_accuracy:0.9850
# Epoch 164, train-loss: 0.0523 - train_accuracy:0.9845 - val_loss:0.0610 -val_accuracy:0.9816
# Epoch 165, train-loss: 0.0521 - train_accuracy:0.9817 - val_loss:0.0669 -val_accuracy:0.9731
# Epoch 166, train-loss: 0.0487 - train_accuracy:0.9820 - val_loss:0.0591 -val_accuracy:0.9816
# Epoch 167, train-loss: 0.0442 - train_accuracy:0.9840 - val_loss:0.0438 -val_accuracy:0.9852
# Epoch 168, train-loss: 0.0464 - train_accuracy:0.9849 - val_loss:0.0952 -val_accuracy:0.9817
# Epoch 169, train-loss: 0.0534 - train_accuracy:0.9845 - val_loss:0.0574 -val_accuracy:0.9818
# Epoch 170, train-loss: 0.0614 - train_accuracy:0.9823 - val_loss:0.0613 -val_accuracy:0.9779
# Epoch 171, train-loss: 0.0549 - train_accuracy:0.9802 - val_loss:0.0473 -val_accuracy:0.9852
# Epoch 172, train-loss: 0.0511 - train_accuracy:0.9813 - val_loss:0.0837 -val_accuracy:0.9805
# Epoch 173, train-loss: 0.0517 - train_accuracy:0.9857 - val_loss:0.0446 -val_accuracy:0.9854
# Epoch 174, train-loss: 0.0501 - train_accuracy:0.9846 - val_loss:0.0499 -val_accuracy:0.9813
# Epoch 175, train-loss: 0.0499 - train_accuracy:0.9823 - val_loss:0.0484 -val_accuracy:0.9845
# Epoch 176, train-loss: 0.0439 - train_accuracy:0.9853 - val_loss:0.0566 -val_accuracy:0.9834
# Epoch 177, train-loss: 0.0460 - train_accuracy:0.9834 - val_loss:0.0555 -val_accuracy:0.9873
# Epoch 178, train-loss: 0.0414 - train_accuracy:0.9864 - val_loss:0.0448 -val_accuracy:0.9850
# Epoch 179, train-loss: 0.0423 - train_accuracy:0.9854 - val_loss:0.0418 -val_accuracy:0.9868
# Epoch 180, train-loss: 0.0385 - train_accuracy:0.9867 - val_loss:0.0629 -val_accuracy:0.9877
# Epoch 181, train-loss: 0.0393 - train_accuracy:0.9869 - val_loss:0.0522 -val_accuracy:0.9876
# Epoch 182, train-loss: 0.0374 - train_accuracy:0.9873 - val_loss:0.0481 -val_accuracy:0.9876
# Epoch 183, train-loss: 0.0373 - train_accuracy:0.9871 - val_loss:0.0457 -val_accuracy:0.9876
# Epoch 184, train-loss: 0.0371 - train_accuracy:0.9871 - val_loss:0.0965 -val_accuracy:0.9726
# Epoch 185, train-loss: 0.0384 - train_accuracy:0.9877 - val_loss:0.0359 -val_accuracy:0.9881
# Epoch 186, train-loss: 0.0372 - train_accuracy:0.9876 - val_loss:0.0544 -val_accuracy:0.9874
# Epoch 187, train-loss: 0.0366 - train_accuracy:0.9877 - val_loss:0.0454 -val_accuracy:0.9875
# Epoch 188, train-loss: 0.0355 - train_accuracy:0.9877 - val_loss:0.0467 -val_accuracy:0.9879
# Epoch 189, train-loss: 0.0357 - train_accuracy:0.9873 - val_loss:0.0417 -val_accuracy:0.9875
# Epoch 190, train-loss: 0.0367 - train_accuracy:0.9871 - val_loss:0.0362 -val_accuracy:0.9892
# Epoch 191, train-loss: 0.0348 - train_accuracy:0.9883 - val_loss:0.0570 -val_accuracy:0.9849
# Epoch 192, train-loss: 0.0352 - train_accuracy:0.9883 - val_loss:0.0369 -val_accuracy:0.9896
# Epoch 193, train-loss: 0.0371 - train_accuracy:0.9875 - val_loss:0.0376 -val_accuracy:0.9894
# Epoch 194, train-loss: 0.0344 - train_accuracy:0.9882 - val_loss:0.0567 -val_accuracy:0.9839
# Epoch 195, train-loss: 0.0340 - train_accuracy:0.9888 - val_loss:0.0417 -val_accuracy:0.9895
# Epoch 196, train-loss: 0.0326 - train_accuracy:0.9887 - val_loss:0.0400 -val_accuracy:0.9883
# Epoch 197, train-loss: 0.0326 - train_accuracy:0.9889 - val_loss:0.0516 -val_accuracy:0.9854
# Epoch 198, train-loss: 0.0320 - train_accuracy:0.9890 - val_loss:0.0417 -val_accuracy:0.9877
# Epoch 199, train-loss: 0.0326 - train_accuracy:0.9888 - val_loss:0.0469 -val_accuracy:0.9866
# Epoch 200, train-loss: 0.0321 - train_accuracy:0.9887 - val_loss:0.0507 -val_accuracy:0.9842
# Epoch 201, train-loss: 0.0304 - train_accuracy:0.9894 - val_loss:0.0437 -val_accuracy:0.9871
# Epoch 202, train-loss: 0.0305 - train_accuracy:0.9894 - val_loss:0.0426 -val_accuracy:0.9873
# Epoch 203, train-loss: 0.0320 - train_accuracy:0.9895 - val_loss:0.0421 -val_accuracy:0.9838
# Epoch 204, train-loss: 0.0380 - train_accuracy:0.9870 - val_loss:0.0445 -val_accuracy:0.9850
# Epoch 205, train-loss: 0.0369 - train_accuracy:0.9869 - val_loss:0.0433 -val_accuracy:0.9836
# Epoch 206, train-loss: 0.0365 - train_accuracy:0.9870 - val_loss:0.1204 -val_accuracy:0.9482
# Epoch 207, train-loss: 0.0371 - train_accuracy:0.9880 - val_loss:0.0330 -val_accuracy:0.9892
# Epoch 208, train-loss: 0.0331 - train_accuracy:0.9885 - val_loss:0.0367 -val_accuracy:0.9893
# Epoch 209, train-loss: 0.0311 - train_accuracy:0.9890 - val_loss:0.0408 -val_accuracy:0.9848
# Epoch 210, train-loss: 0.0322 - train_accuracy:0.9886 - val_loss:0.0437 -val_accuracy:0.9874
# Epoch 211, train-loss: 0.0301 - train_accuracy:0.9895 - val_loss:0.0368 -val_accuracy:0.9867
# Epoch 212, train-loss: 0.0295 - train_accuracy:0.9897 - val_loss:0.0783 -val_accuracy:0.9698
# Epoch 213, train-loss: 0.0305 - train_accuracy:0.9891 - val_loss:0.0449 -val_accuracy:0.9832
# Epoch 214, train-loss: 0.0310 - train_accuracy:0.9887 - val_loss:0.0505 -val_accuracy:0.9828
# Epoch 215, train-loss: 0.0303 - train_accuracy:0.9890 - val_loss:0.0416 -val_accuracy:0.9854
# Epoch 216, train-loss: 0.0312 - train_accuracy:0.9888 - val_loss:0.2179 -val_accuracy:0.8952
# Epoch 217, train-loss: 0.0333 - train_accuracy:0.9887 - val_loss:0.0344 -val_accuracy:0.9877
# Epoch 218, train-loss: 0.0312 - train_accuracy:0.9888 - val_loss:0.0483 -val_accuracy:0.9834
# Epoch 219, train-loss: 0.0313 - train_accuracy:0.9887 - val_loss:0.0399 -val_accuracy:0.9859
# Epoch 220, train-loss: 0.0295 - train_accuracy:0.9894 - val_loss:0.0837 -val_accuracy:0.9668
# Epoch 221, train-loss: 0.0297 - train_accuracy:0.9895 - val_loss:0.0389 -val_accuracy:0.9868
# Epoch 222, train-loss: 0.0298 - train_accuracy:0.9896 - val_loss:0.1115 -val_accuracy:0.9520
# Epoch 223, train-loss: 0.0302 - train_accuracy:0.9894 - val_loss:0.0421 -val_accuracy:0.9849
# Epoch 224, train-loss: 0.0325 - train_accuracy:0.9887 - val_loss:0.0307 -val_accuracy:0.9904
# Epoch 225, train-loss: 0.0310 - train_accuracy:0.9889 - val_loss:0.0322 -val_accuracy:0.9891
# Epoch 226, train-loss: 0.0290 - train_accuracy:0.9897 - val_loss:0.0505 -val_accuracy:0.9832
# Epoch 227, train-loss: 0.0283 - train_accuracy:0.9903 - val_loss:0.0421 -val_accuracy:0.9864
# Epoch 228, train-loss: 0.0286 - train_accuracy:0.9901 - val_loss:0.0304 -val_accuracy:0.9905
# Epoch 229, train-loss: 0.0278 - train_accuracy:0.9901 - val_loss:0.0411 -val_accuracy:0.9862
# Epoch 230, train-loss: 0.0282 - train_accuracy:0.9897 - val_loss:0.0764 -val_accuracy:0.9694
# Epoch 231, train-loss: 0.0271 - train_accuracy:0.9905 - val_loss:0.0392 -val_accuracy:0.9866
# Epoch 232, train-loss: 0.0264 - train_accuracy:0.9908 - val_loss:0.0809 -val_accuracy:0.9682
# Epoch 233, train-loss: 0.0259 - train_accuracy:0.9909 - val_loss:0.0437 -val_accuracy:0.9841
# Epoch 234, train-loss: 0.0259 - train_accuracy:0.9907 - val_loss:0.0526 -val_accuracy:0.9800
# Epoch 235, train-loss: 0.0256 - train_accuracy:0.9909 - val_loss:0.0486 -val_accuracy:0.9813
# Epoch 236, train-loss: 0.0258 - train_accuracy:0.9908 - val_loss:0.0840 -val_accuracy:0.9673
# Epoch 237, train-loss: 0.0248 - train_accuracy:0.9912 - val_loss:0.0376 -val_accuracy:0.9865
# Epoch 238, train-loss: 0.0258 - train_accuracy:0.9909 - val_loss:0.0487 -val_accuracy:0.9817
# Epoch 239, train-loss: 0.0255 - train_accuracy:0.9909 - val_loss:0.0566 -val_accuracy:0.9783
# Epoch 240, train-loss: 0.0251 - train_accuracy:0.9910 - val_loss:0.0701 -val_accuracy:0.9720
# Epoch 241, train-loss: 0.0245 - train_accuracy:0.9914 - val_loss:0.0623 -val_accuracy:0.9756
# Epoch 242, train-loss: 0.0240 - train_accuracy:0.9915 - val_loss:0.0412 -val_accuracy:0.9854
# Epoch 243, train-loss: 0.0245 - train_accuracy:0.9915 - val_loss:0.0437 -val_accuracy:0.9839
# Epoch 244, train-loss: 0.0241 - train_accuracy:0.9914 - val_loss:0.0971 -val_accuracy:0.9632
# Epoch 245, train-loss: 0.0246 - train_accuracy:0.9910 - val_loss:0.0726 -val_accuracy:0.9711
# Epoch 246, train-loss: 0.0240 - train_accuracy:0.9914 - val_loss:0.0596 -val_accuracy:0.9767
# Epoch 247, train-loss: 0.0238 - train_accuracy:0.9915 - val_loss:0.0520 -val_accuracy:0.9803
# Epoch 248, train-loss: 0.0233 - train_accuracy:0.9917 - val_loss:0.0359 -val_accuracy:0.9870
# Epoch 249, train-loss: 0.0241 - train_accuracy:0.9914 - val_loss:0.0707 -val_accuracy:0.9723
# Epoch 250, train-loss: 0.0236 - train_accuracy:0.9916 - val_loss:0.0910 -val_accuracy:0.9652

# %%
# plot loss and accuracy
plot_history(history)

# %% [markdown]
# ## (3) Test and evaluate our model

# %%
# predict the test set
def predict(net, test_loader):
    net.eval()
    predictions = []
    acc_accuracy = []
    for image, label in test_loader:
        image = image.to(device)
        label = label.to(device)
        pred = net(image)
        pred = activation(pred)
        accuracy = calc_accuracy(pred, label)
        acc_accuracy.append(float(accuracy.cpu().detach().numpy()))
        image = np.squeeze(image.cpu())
        pred = np.squeeze(pred.cpu().detach().numpy(),0)
        predictions.append(pred)
    acc_accuracy = []
    return predictions, float(accuracy.cpu().numpy())
    
# plot predicted results
predictions, accuracy = predict(net, test_loader)
predictions = np.stack(predictions, axis=0)
print('Accuracy: {:.3f}'.format(accuracy))
show_predictions(x_test, y_test, predictions)
# Out:
# Accuracy: 0.870

# %% [markdown]
# ### A1: Continue training for more epochs

# %%
# continue training, takes ~3min
# heads up: the "net" variable still carries all the information from the previous training
num_epochs2=160
net, continued_history, optimizer = train(net, epochs=num_epochs2, learning_rate=1e-4, start_epoch=num_epochs1,history=history, optimizer=optimizer)

print('Finished Training')
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]
# Epoch 251, train-loss: 0.0213 - train_accuracy:0.9927 - val_loss:0.0637 -val_accuracy:0.9754
# Epoch 252, train-loss: 0.0216 - train_accuracy:0.9925 - val_loss:0.0914 -val_accuracy:0.9639
# Epoch 253, train-loss: 0.0223 - train_accuracy:0.9925 - val_loss:0.0392 -val_accuracy:0.9872
# Epoch 254, train-loss: 0.0209 - train_accuracy:0.9928 - val_loss:0.0911 -val_accuracy:0.9627
# Epoch 255, train-loss: 0.0208 - train_accuracy:0.9930 - val_loss:0.0494 -val_accuracy:0.9820
# Epoch 256, train-loss: 0.0204 - train_accuracy:0.9930 - val_loss:0.0508 -val_accuracy:0.9817
# Epoch 257, train-loss: 0.0204 - train_accuracy:0.9931 - val_loss:0.0922 -val_accuracy:0.9628
# Epoch 258, train-loss: 0.0203 - train_accuracy:0.9932 - val_loss:0.0870 -val_accuracy:0.9645
# Epoch 259, train-loss: 0.0205 - train_accuracy:0.9931 - val_loss:0.0426 -val_accuracy:0.9852
# Epoch 260, train-loss: 0.0202 - train_accuracy:0.9931 - val_loss:0.0995 -val_accuracy:0.9610
# Epoch 261, train-loss: 0.0208 - train_accuracy:0.9931 - val_loss:0.2013 -val_accuracy:0.9218
# Epoch 262, train-loss: 0.0206 - train_accuracy:0.9931 - val_loss:0.1562 -val_accuracy:0.9378
# Epoch 263, train-loss: 0.0212 - train_accuracy:0.9928 - val_loss:0.0279 -val_accuracy:0.9906
# Epoch 264, train-loss: 0.0219 - train_accuracy:0.9923 - val_loss:0.0321 -val_accuracy:0.9898
# Epoch 265, train-loss: 0.0199 - train_accuracy:0.9930 - val_loss:0.0479 -val_accuracy:0.9835
# Epoch 266, train-loss: 0.0198 - train_accuracy:0.9933 - val_loss:0.0285 -val_accuracy:0.9907
# Epoch 267, train-loss: 0.0215 - train_accuracy:0.9927 - val_loss:0.0455 -val_accuracy:0.9843
# Epoch 268, train-loss: 0.0196 - train_accuracy:0.9933 - val_loss:0.0793 -val_accuracy:0.9687
# Epoch 269, train-loss: 0.0195 - train_accuracy:0.9935 - val_loss:0.0718 -val_accuracy:0.9722
# Epoch 270, train-loss: 0.0198 - train_accuracy:0.9933 - val_loss:0.0564 -val_accuracy:0.9790
# Epoch 271, train-loss: 0.0195 - train_accuracy:0.9935 - val_loss:0.1102 -val_accuracy:0.9566
# Epoch 272, train-loss: 0.0190 - train_accuracy:0.9938 - val_loss:0.0733 -val_accuracy:0.9717
# Epoch 273, train-loss: 0.0185 - train_accuracy:0.9939 - val_loss:0.0528 -val_accuracy:0.9808
# Epoch 274, train-loss: 0.0190 - train_accuracy:0.9937 - val_loss:0.0430 -val_accuracy:0.9849
# Epoch 275, train-loss: 0.0189 - train_accuracy:0.9934 - val_loss:0.0730 -val_accuracy:0.9723
# Epoch 276, train-loss: 0.0203 - train_accuracy:0.9932 - val_loss:0.1423 -val_accuracy:0.9450
# Epoch 277, train-loss: 0.0210 - train_accuracy:0.9925 - val_loss:0.0333 -val_accuracy:0.9888
# Epoch 278, train-loss: 0.0263 - train_accuracy:0.9905 - val_loss:0.0274 -val_accuracy:0.9916
# Epoch 279, train-loss: 0.0239 - train_accuracy:0.9920 - val_loss:0.2113 -val_accuracy:0.9114
# Epoch 280, train-loss: 0.0253 - train_accuracy:0.9912 - val_loss:0.0403 -val_accuracy:0.9869
# Epoch 281, train-loss: 0.0338 - train_accuracy:0.9897 - val_loss:0.0366 -val_accuracy:0.9851
# Epoch 282, train-loss: 0.0306 - train_accuracy:0.9895 - val_loss:0.0212 -val_accuracy:0.9931
# Epoch 283, train-loss: 0.0276 - train_accuracy:0.9912 - val_loss:0.0336 -val_accuracy:0.9917
# Epoch 284, train-loss: 0.0218 - train_accuracy:0.9931 - val_loss:0.1842 -val_accuracy:0.9258
# Epoch 285, train-loss: 0.0559 - train_accuracy:0.9841 - val_loss:0.0424 -val_accuracy:0.9862
# Epoch 286, train-loss: 0.4647 - train_accuracy:0.9477 - val_loss:0.2718 -val_accuracy:0.9487
# Epoch 287, train-loss: 0.1917 - train_accuracy:0.9583 - val_loss:0.2843 -val_accuracy:0.9827
# Epoch 288, train-loss: 0.2288 - train_accuracy:0.9841 - val_loss:0.1788 -val_accuracy:0.9545
# Epoch 289, train-loss: 0.1760 - train_accuracy:0.9380 - val_loss:0.1898 -val_accuracy:0.9297
# Epoch 290, train-loss: 0.1793 - train_accuracy:0.9380 - val_loss:0.1991 -val_accuracy:0.9630
# Epoch 291, train-loss: 0.1600 - train_accuracy:0.9603 - val_loss:0.1473 -val_accuracy:0.9526
# Epoch 292, train-loss: 0.1325 - train_accuracy:0.9501 - val_loss:0.1174 -val_accuracy:0.9741
# Epoch 293, train-loss: 0.1000 - train_accuracy:0.9753 - val_loss:0.1012 -val_accuracy:0.9813
# Epoch 294, train-loss: 0.0770 - train_accuracy:0.9770 - val_loss:0.0680 -val_accuracy:0.9818
# Epoch 295, train-loss: 0.0661 - train_accuracy:0.9810 - val_loss:0.0908 -val_accuracy:0.9756
# Epoch 296, train-loss: 0.0564 - train_accuracy:0.9828 - val_loss:0.0567 -val_accuracy:0.9825
# Epoch 297, train-loss: 0.0564 - train_accuracy:0.9833 - val_loss:0.0868 -val_accuracy:0.9727
# Epoch 298, train-loss: 0.0585 - train_accuracy:0.9811 - val_loss:0.0778 -val_accuracy:0.9753
# Epoch 299, train-loss: 0.0554 - train_accuracy:0.9835 - val_loss:0.0604 -val_accuracy:0.9801
# Epoch 300, train-loss: 0.0579 - train_accuracy:0.9818 - val_loss:0.1256 -val_accuracy:0.9659
# Epoch 301, train-loss: 0.0526 - train_accuracy:0.9846 - val_loss:0.0496 -val_accuracy:0.9841
# Epoch 302, train-loss: 0.0516 - train_accuracy:0.9845 - val_loss:0.1313 -val_accuracy:0.9667
# Epoch 303, train-loss: 0.0487 - train_accuracy:0.9843 - val_loss:0.0560 -val_accuracy:0.9828
# Epoch 304, train-loss: 0.0508 - train_accuracy:0.9850 - val_loss:0.0628 -val_accuracy:0.9817
# Epoch 305, train-loss: 0.0487 - train_accuracy:0.9849 - val_loss:0.1022 -val_accuracy:0.9745
# Epoch 306, train-loss: 0.0521 - train_accuracy:0.9846 - val_loss:0.0478 -val_accuracy:0.9854
# Epoch 307, train-loss: 0.0471 - train_accuracy:0.9854 - val_loss:0.1121 -val_accuracy:0.9734
# Epoch 308, train-loss: 0.0462 - train_accuracy:0.9855 - val_loss:0.0521 -val_accuracy:0.9849
# Epoch 309, train-loss: 0.0443 - train_accuracy:0.9864 - val_loss:0.0701 -val_accuracy:0.9821
# Epoch 310, train-loss: 0.0417 - train_accuracy:0.9871 - val_loss:0.0639 -val_accuracy:0.9837
# Epoch 311, train-loss: 0.0416 - train_accuracy:0.9871 - val_loss:0.0638 -val_accuracy:0.9840
# Epoch 312, train-loss: 0.0403 - train_accuracy:0.9876 - val_loss:0.0577 -val_accuracy:0.9854
# Epoch 313, train-loss: 0.0409 - train_accuracy:0.9875 - val_loss:0.0703 -val_accuracy:0.9838
# Epoch 314, train-loss: 0.0397 - train_accuracy:0.9878 - val_loss:0.0503 -val_accuracy:0.9870
# Epoch 315, train-loss: 0.0391 - train_accuracy:0.9879 - val_loss:0.0718 -val_accuracy:0.9841
# Epoch 316, train-loss: 0.0387 - train_accuracy:0.9880 - val_loss:0.0655 -val_accuracy:0.9857
# Epoch 317, train-loss: 0.0412 - train_accuracy:0.9876 - val_loss:0.0486 -val_accuracy:0.9880
# Epoch 318, train-loss: 0.0381 - train_accuracy:0.9885 - val_loss:0.0893 -val_accuracy:0.9809
# Epoch 319, train-loss: 0.0370 - train_accuracy:0.9885 - val_loss:0.0396 -val_accuracy:0.9885
# Epoch 320, train-loss: 0.0403 - train_accuracy:0.9880 - val_loss:0.0636 -val_accuracy:0.9868
# Epoch 321, train-loss: 0.0367 - train_accuracy:0.9887 - val_loss:0.0589 -val_accuracy:0.9874
# Epoch 322, train-loss: 0.0354 - train_accuracy:0.9889 - val_loss:0.0464 -val_accuracy:0.9892
# Epoch 323, train-loss: 0.0352 - train_accuracy:0.9890 - val_loss:0.0541 -val_accuracy:0.9891
# Epoch 324, train-loss: 0.0344 - train_accuracy:0.9893 - val_loss:0.0511 -val_accuracy:0.9899
# Epoch 325, train-loss: 0.0343 - train_accuracy:0.9894 - val_loss:0.0572 -val_accuracy:0.9899
# Epoch 326, train-loss: 0.0338 - train_accuracy:0.9896 - val_loss:0.0479 -val_accuracy:0.9907
# Epoch 327, train-loss: 0.0345 - train_accuracy:0.9894 - val_loss:0.0444 -val_accuracy:0.9907
# Epoch 328, train-loss: 0.0330 - train_accuracy:0.9895 - val_loss:0.0550 -val_accuracy:0.9908
# Epoch 329, train-loss: 0.0328 - train_accuracy:0.9898 - val_loss:0.0479 -val_accuracy:0.9906
# Epoch 330, train-loss: 0.0329 - train_accuracy:0.9899 - val_loss:0.0565 -val_accuracy:0.9911
# Epoch 331, train-loss: 0.0321 - train_accuracy:0.9902 - val_loss:0.0442 -val_accuracy:0.9912
# Epoch 332, train-loss: 0.0310 - train_accuracy:0.9902 - val_loss:0.0453 -val_accuracy:0.9912
# Epoch 333, train-loss: 0.0309 - train_accuracy:0.9902 - val_loss:0.0449 -val_accuracy:0.9905
# Epoch 334, train-loss: 0.0311 - train_accuracy:0.9903 - val_loss:0.0481 -val_accuracy:0.9912
# Epoch 335, train-loss: 0.0295 - train_accuracy:0.9906 - val_loss:0.0465 -val_accuracy:0.9917
# Epoch 336, train-loss: 0.0291 - train_accuracy:0.9908 - val_loss:0.0391 -val_accuracy:0.9910
# Epoch 337, train-loss: 0.0290 - train_accuracy:0.9908 - val_loss:0.0458 -val_accuracy:0.9916
# Epoch 338, train-loss: 0.0285 - train_accuracy:0.9909 - val_loss:0.0436 -val_accuracy:0.9913
# Epoch 339, train-loss: 0.0281 - train_accuracy:0.9912 - val_loss:0.0415 -val_accuracy:0.9905
# Epoch 340, train-loss: 0.0279 - train_accuracy:0.9911 - val_loss:0.0427 -val_accuracy:0.9914
# Epoch 341, train-loss: 0.0275 - train_accuracy:0.9912 - val_loss:0.0407 -val_accuracy:0.9913
# Epoch 342, train-loss: 0.0273 - train_accuracy:0.9914 - val_loss:0.0435 -val_accuracy:0.9912
# Epoch 343, train-loss: 0.0272 - train_accuracy:0.9915 - val_loss:0.0373 -val_accuracy:0.9911
# Epoch 344, train-loss: 0.0271 - train_accuracy:0.9916 - val_loss:0.0445 -val_accuracy:0.9915
# Epoch 345, train-loss: 0.0258 - train_accuracy:0.9918 - val_loss:0.0397 -val_accuracy:0.9905
# Epoch 346, train-loss: 0.0263 - train_accuracy:0.9919 - val_loss:0.0421 -val_accuracy:0.9910
# Epoch 347, train-loss: 0.0251 - train_accuracy:0.9921 - val_loss:0.0402 -val_accuracy:0.9911
# Epoch 348, train-loss: 0.0250 - train_accuracy:0.9921 - val_loss:0.0414 -val_accuracy:0.9917
# Epoch 349, train-loss: 0.0246 - train_accuracy:0.9923 - val_loss:0.0455 -val_accuracy:0.9914
# Epoch 350, train-loss: 0.0246 - train_accuracy:0.9924 - val_loss:0.0418 -val_accuracy:0.9901
# Epoch 351, train-loss: 0.0249 - train_accuracy:0.9920 - val_loss:0.0503 -val_accuracy:0.9899
# Epoch 352, train-loss: 0.0249 - train_accuracy:0.9922 - val_loss:0.0340 -val_accuracy:0.9913
# Epoch 353, train-loss: 0.0239 - train_accuracy:0.9925 - val_loss:0.0573 -val_accuracy:0.9888
# Epoch 354, train-loss: 0.0255 - train_accuracy:0.9923 - val_loss:0.0355 -val_accuracy:0.9898
# Epoch 355, train-loss: 0.0258 - train_accuracy:0.9917 - val_loss:0.0383 -val_accuracy:0.9917
# Epoch 356, train-loss: 0.0256 - train_accuracy:0.9914 - val_loss:0.0381 -val_accuracy:0.9922
# Epoch 357, train-loss: 0.0239 - train_accuracy:0.9925 - val_loss:0.0468 -val_accuracy:0.9905
# Epoch 358, train-loss: 0.0239 - train_accuracy:0.9928 - val_loss:0.0558 -val_accuracy:0.9906
# Epoch 359, train-loss: 0.0236 - train_accuracy:0.9928 - val_loss:0.0336 -val_accuracy:0.9928
# Epoch 360, train-loss: 0.0239 - train_accuracy:0.9926 - val_loss:0.0300 -val_accuracy:0.9926
# Epoch 361, train-loss: 0.0242 - train_accuracy:0.9923 - val_loss:0.0373 -val_accuracy:0.9909
# Epoch 362, train-loss: 0.0225 - train_accuracy:0.9930 - val_loss:0.0373 -val_accuracy:0.9902
# Epoch 363, train-loss: 0.0225 - train_accuracy:0.9932 - val_loss:0.0503 -val_accuracy:0.9883
# Epoch 364, train-loss: 0.0224 - train_accuracy:0.9930 - val_loss:0.0322 -val_accuracy:0.9915
# Epoch 365, train-loss: 0.0223 - train_accuracy:0.9930 - val_loss:0.0311 -val_accuracy:0.9921
# Epoch 366, train-loss: 0.0213 - train_accuracy:0.9932 - val_loss:0.0353 -val_accuracy:0.9914
# Epoch 367, train-loss: 0.0212 - train_accuracy:0.9934 - val_loss:0.0397 -val_accuracy:0.9899
# Epoch 368, train-loss: 0.0210 - train_accuracy:0.9936 - val_loss:0.0380 -val_accuracy:0.9907
# Epoch 369, train-loss: 0.0208 - train_accuracy:0.9935 - val_loss:0.0350 -val_accuracy:0.9913
# Epoch 370, train-loss: 0.0206 - train_accuracy:0.9937 - val_loss:0.0323 -val_accuracy:0.9915
# Epoch 371, train-loss: 0.0205 - train_accuracy:0.9936 - val_loss:0.0374 -val_accuracy:0.9901
# Epoch 372, train-loss: 0.0212 - train_accuracy:0.9935 - val_loss:0.0350 -val_accuracy:0.9907
# Epoch 373, train-loss: 0.0201 - train_accuracy:0.9936 - val_loss:0.0408 -val_accuracy:0.9888
# Epoch 374, train-loss: 0.0202 - train_accuracy:0.9938 - val_loss:0.0339 -val_accuracy:0.9912
# Epoch 375, train-loss: 0.0199 - train_accuracy:0.9939 - val_loss:0.0362 -val_accuracy:0.9907
# Epoch 376, train-loss: 0.0198 - train_accuracy:0.9938 - val_loss:0.0338 -val_accuracy:0.9906
# Epoch 377, train-loss: 0.0200 - train_accuracy:0.9938 - val_loss:0.0337 -val_accuracy:0.9913
# Epoch 378, train-loss: 0.0198 - train_accuracy:0.9936 - val_loss:0.0314 -val_accuracy:0.9910
# Epoch 379, train-loss: 0.0198 - train_accuracy:0.9938 - val_loss:0.0411 -val_accuracy:0.9881
# Epoch 380, train-loss: 0.0195 - train_accuracy:0.9939 - val_loss:0.0319 -val_accuracy:0.9914
# Epoch 381, train-loss: 0.0192 - train_accuracy:0.9941 - val_loss:0.0307 -val_accuracy:0.9920
# Epoch 382, train-loss: 0.0189 - train_accuracy:0.9940 - val_loss:0.0329 -val_accuracy:0.9911
# Epoch 383, train-loss: 0.0191 - train_accuracy:0.9940 - val_loss:0.0365 -val_accuracy:0.9896
# Epoch 384, train-loss: 0.0186 - train_accuracy:0.9941 - val_loss:0.0338 -val_accuracy:0.9902
# Epoch 385, train-loss: 0.0187 - train_accuracy:0.9941 - val_loss:0.0365 -val_accuracy:0.9893
# Epoch 386, train-loss: 0.0186 - train_accuracy:0.9941 - val_loss:0.0340 -val_accuracy:0.9903
# Epoch 387, train-loss: 0.0186 - train_accuracy:0.9942 - val_loss:0.0298 -val_accuracy:0.9914
# Epoch 388, train-loss: 0.0180 - train_accuracy:0.9943 - val_loss:0.0372 -val_accuracy:0.9892
# Epoch 389, train-loss: 0.0189 - train_accuracy:0.9941 - val_loss:0.0313 -val_accuracy:0.9913
# Epoch 390, train-loss: 0.0186 - train_accuracy:0.9941 - val_loss:0.0307 -val_accuracy:0.9912
# Epoch 391, train-loss: 0.0191 - train_accuracy:0.9939 - val_loss:0.0342 -val_accuracy:0.9901
# Epoch 392, train-loss: 0.0183 - train_accuracy:0.9942 - val_loss:0.0393 -val_accuracy:0.9884
# Epoch 393, train-loss: 0.0184 - train_accuracy:0.9943 - val_loss:0.0305 -val_accuracy:0.9912
# Epoch 394, train-loss: 0.0183 - train_accuracy:0.9943 - val_loss:0.0373 -val_accuracy:0.9890
# Epoch 395, train-loss: 0.0182 - train_accuracy:0.9943 - val_loss:0.0367 -val_accuracy:0.9890
# Epoch 396, train-loss: 0.0178 - train_accuracy:0.9945 - val_loss:0.0337 -val_accuracy:0.9907
# Epoch 397, train-loss: 0.0181 - train_accuracy:0.9943 - val_loss:0.0286 -val_accuracy:0.9920
# Epoch 398, train-loss: 0.0175 - train_accuracy:0.9945 - val_loss:0.0361 -val_accuracy:0.9896
# Epoch 399, train-loss: 0.0174 - train_accuracy:0.9944 - val_loss:0.0281 -val_accuracy:0.9916
# Epoch 400, train-loss: 0.0176 - train_accuracy:0.9944 - val_loss:0.0279 -val_accuracy:0.9920
# Epoch 401, train-loss: 0.0171 - train_accuracy:0.9945 - val_loss:0.0261 -val_accuracy:0.9922
# Epoch 402, train-loss: 0.0176 - train_accuracy:0.9943 - val_loss:0.0326 -val_accuracy:0.9907
# Epoch 403, train-loss: 0.0173 - train_accuracy:0.9943 - val_loss:0.0287 -val_accuracy:0.9912
# Epoch 404, train-loss: 0.0177 - train_accuracy:0.9944 - val_loss:0.0286 -val_accuracy:0.9917
# Epoch 405, train-loss: 0.0168 - train_accuracy:0.9946 - val_loss:0.0253 -val_accuracy:0.9926
# Epoch 406, train-loss: 0.0180 - train_accuracy:0.9945 - val_loss:0.0251 -val_accuracy:0.9928
# Epoch 407, train-loss: 0.0179 - train_accuracy:0.9943 - val_loss:0.0296 -val_accuracy:0.9917
# Epoch 408, train-loss: 0.0185 - train_accuracy:0.9939 - val_loss:0.0277 -val_accuracy:0.9923
# Epoch 409, train-loss: 0.0200 - train_accuracy:0.9936 - val_loss:0.0340 -val_accuracy:0.9890
# Epoch 410, train-loss: 0.0194 - train_accuracy:0.9937 - val_loss:0.0483 -val_accuracy:0.9841
# Finished Training

# %%
# plot loss and accuracy
plot_history(history)

# %%
test = predictions[0][0]

# %%
# evaluate and plot predicted results
predictions, accuracy = predict(net, test_loader)
predictions = np.stack(predictions, axis=0)
print('Accuracy: {:.3f}'.format(accuracy))
show_predictions(x_test, y_test, predictions)
# Out:
# Accuracy: 0.954

# %% [markdown]
# #### The training of the networks depend on many hyperparameters such as
# - network architecture: #layers, #fmaps
# - batch size, learning rate
# - number and distribution of the training samples
#
# #### You can play and see how these settings influence the learning curve.

# %% [markdown]
# ![](example_learning_curves/lc_all.png)

# %% [markdown]
# ### A2: Use early stopping to avoid overfitting

# %%
class EarlyStopping():
    """
    Early stopping to stop the training when the loss does not improve after
    certain epochs.
    Code from https://debuggercafe.com/using-learning-rate-scheduler-and-early-stopping-with-pytorch/
    """
    def __init__(self, patience=20, min_delta=0):
        """
        :param patience: how many epochs to wait before stopping when loss is
               not improving
        :param min_delta: minimum difference between new loss and old loss for
               new loss to be considered as an improvement
        """
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# define model
out_channels = 1
d_factors = [[2,2],[2,2],[2,2],[2,2]]
activation = torch.nn.Sigmoid()
early_stopping = EarlyStopping(patience=60)

net = torch.nn.Sequential(
    UNet(in_channels=1,
    num_fmaps=6,
    fmap_inc_factors=2,
    downsample_factors=d_factors,
    activation='ReLU',
    padding='same',
    num_fmaps_out=6,
    constant_upsample=False
    ),
    torch.nn.Conv2d(in_channels=6, out_channels=out_channels, kernel_size=1, padding=0, bias=True))

# %%
# train model
epochs = 500
net, history_w_ea,_ = train(net, epochs, learning_rate=5e-4, early_stopping=early_stopping)
print('Finished Training')
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch 1, train-loss: 0.5456 - train_accuracy:0.9295 - val_loss:0.5452 -val_accuracy:0.9294
# Epoch 2, train-loss: 0.5448 - train_accuracy:0.9295 - val_loss:0.5441 -val_accuracy:0.9294
# Epoch 3, train-loss: 0.5436 - train_accuracy:0.9295 - val_loss:0.5428 -val_accuracy:0.9294
# Epoch 4, train-loss: 0.5423 - train_accuracy:0.9295 - val_loss:0.5413 -val_accuracy:0.9294
# Epoch 5, train-loss: 0.5408 - train_accuracy:0.9295 - val_loss:0.5397 -val_accuracy:0.9294
# Epoch 6, train-loss: 0.5390 - train_accuracy:0.9295 - val_loss:0.5376 -val_accuracy:0.9294
# Epoch 7, train-loss: 0.5367 - train_accuracy:0.9295 - val_loss:0.5348 -val_accuracy:0.9294
# Epoch 8, train-loss: 0.5338 - train_accuracy:0.9295 - val_loss:0.5318 -val_accuracy:0.9294
# Epoch 9, train-loss: 0.5308 - train_accuracy:0.9295 - val_loss:0.5286 -val_accuracy:0.9294
# Epoch 10, train-loss: 0.5275 - train_accuracy:0.9295 - val_loss:0.5250 -val_accuracy:0.9294
# Epoch 11, train-loss: 0.5238 - train_accuracy:0.9295 - val_loss:0.5210 -val_accuracy:0.9294
# Epoch 12, train-loss: 0.5196 - train_accuracy:0.9295 - val_loss:0.5164 -val_accuracy:0.9294
# Epoch 13, train-loss: 0.5149 - train_accuracy:0.9295 - val_loss:0.5111 -val_accuracy:0.9294
# Epoch 14, train-loss: 0.5094 - train_accuracy:0.9295 - val_loss:0.5049 -val_accuracy:0.9294
# Epoch 15, train-loss: 0.5029 - train_accuracy:0.9295 - val_loss:0.4972 -val_accuracy:0.9294
# Epoch 16, train-loss: 0.4944 - train_accuracy:0.9295 - val_loss:0.4869 -val_accuracy:0.9294
# Epoch 17, train-loss: 0.4833 - train_accuracy:0.9295 - val_loss:0.4735 -val_accuracy:0.9294
# Epoch 18, train-loss: 0.4684 - train_accuracy:0.9295 - val_loss:0.4533 -val_accuracy:0.9294
# Epoch 19, train-loss: 0.4426 - train_accuracy:0.9295 - val_loss:0.4030 -val_accuracy:0.9294
# Epoch 20, train-loss: 0.3587 - train_accuracy:0.9295 - val_loss:0.3027 -val_accuracy:0.9294
# Epoch 21, train-loss: 0.3099 - train_accuracy:0.9295 - val_loss:0.2822 -val_accuracy:0.9294
# Epoch 22, train-loss: 0.2928 - train_accuracy:0.9295 - val_loss:0.2987 -val_accuracy:0.9294
# Epoch 23, train-loss: 0.2912 - train_accuracy:0.9295 - val_loss:0.2734 -val_accuracy:0.9294
# Epoch 24, train-loss: 0.2771 - train_accuracy:0.9295 - val_loss:0.2725 -val_accuracy:0.9294
# Epoch 25, train-loss: 0.2670 - train_accuracy:0.9295 - val_loss:0.2676 -val_accuracy:0.9294
# Epoch 26, train-loss: 0.2636 - train_accuracy:0.9295 - val_loss:0.2566 -val_accuracy:0.9294
# Epoch 27, train-loss: 0.2513 - train_accuracy:0.9295 - val_loss:0.2496 -val_accuracy:0.9294
# Epoch 28, train-loss: 0.2420 - train_accuracy:0.9295 - val_loss:0.2453 -val_accuracy:0.9294
# Epoch 29, train-loss: 0.2318 - train_accuracy:0.9295 - val_loss:0.2278 -val_accuracy:0.9294
# Epoch 30, train-loss: 0.2173 - train_accuracy:0.9295 - val_loss:0.2188 -val_accuracy:0.9294
# Epoch 31, train-loss: 0.1975 - train_accuracy:0.9295 - val_loss:0.1912 -val_accuracy:0.9294
# Epoch 32, train-loss: 0.1762 - train_accuracy:0.9295 - val_loss:0.1693 -val_accuracy:0.9294
# Epoch 33, train-loss: 0.1555 - train_accuracy:0.9295 - val_loss:0.1872 -val_accuracy:0.9294
# Epoch 34, train-loss: 0.1379 - train_accuracy:0.9295 - val_loss:0.2615 -val_accuracy:0.9294
# Epoch 35, train-loss: 0.1249 - train_accuracy:0.9295 - val_loss:0.1237 -val_accuracy:0.9294
# Epoch 36, train-loss: 0.1892 - train_accuracy:0.9295 - val_loss:0.1622 -val_accuracy:0.9294
# Epoch 37, train-loss: 0.1537 - train_accuracy:0.9295 - val_loss:0.1278 -val_accuracy:0.9295
# Epoch 38, train-loss: 0.1372 - train_accuracy:0.9348 - val_loss:0.2460 -val_accuracy:0.9460
# Epoch 39, train-loss: 0.1362 - train_accuracy:0.9458 - val_loss:0.1133 -val_accuracy:0.9488
# Epoch 40, train-loss: 0.1181 - train_accuracy:0.9462 - val_loss:0.1202 -val_accuracy:0.9495
# Epoch 41, train-loss: 0.1151 - train_accuracy:0.9522 - val_loss:0.1198 -val_accuracy:0.9604
# Epoch 42, train-loss: 0.1119 - train_accuracy:0.9643 - val_loss:0.1464 -val_accuracy:0.9656
# Epoch 43, train-loss: 0.1040 - train_accuracy:0.9677 - val_loss:0.1018 -val_accuracy:0.9650
# Epoch 44, train-loss: 0.1005 - train_accuracy:0.9668 - val_loss:0.0981 -val_accuracy:0.9688
# Epoch 45, train-loss: 0.0939 - train_accuracy:0.9718 - val_loss:0.1239 -val_accuracy:0.9754
# Epoch 46, train-loss: 0.0941 - train_accuracy:0.9781 - val_loss:0.1412 -val_accuracy:0.9771
# Epoch 47, train-loss: 0.0914 - train_accuracy:0.9769 - val_loss:0.1015 -val_accuracy:0.9768
# Epoch 48, train-loss: 0.0857 - train_accuracy:0.9789 - val_loss:0.1413 -val_accuracy:0.9806
# Epoch 49, train-loss: 0.0834 - train_accuracy:0.9811 - val_loss:0.1148 -val_accuracy:0.9804
# Epoch 50, train-loss: 0.0800 - train_accuracy:0.9809 - val_loss:0.0957 -val_accuracy:0.9792
# Epoch 51, train-loss: 0.0769 - train_accuracy:0.9814 - val_loss:0.0940 -val_accuracy:0.9782
# Epoch 52, train-loss: 0.0742 - train_accuracy:0.9817 - val_loss:0.0891 -val_accuracy:0.9723
# Epoch 53, train-loss: 0.0724 - train_accuracy:0.9803 - val_loss:0.0911 -val_accuracy:0.9786
# Epoch 54, train-loss: 0.0685 - train_accuracy:0.9836 - val_loss:0.1080 -val_accuracy:0.9821
# Epoch 55, train-loss: 0.0676 - train_accuracy:0.9840 - val_loss:0.0862 -val_accuracy:0.9792
# Epoch 56, train-loss: 0.0662 - train_accuracy:0.9833 - val_loss:0.0841 -val_accuracy:0.9786
# Epoch 57, train-loss: 0.0663 - train_accuracy:0.9831 - val_loss:0.1011 -val_accuracy:0.9814
# Epoch 58, train-loss: 0.0665 - train_accuracy:0.9829 - val_loss:0.1209 -val_accuracy:0.9832
# Epoch 59, train-loss: 0.0666 - train_accuracy:0.9833 - val_loss:0.1215 -val_accuracy:0.9833
# Epoch 60, train-loss: 0.0662 - train_accuracy:0.9820 - val_loss:0.1068 -val_accuracy:0.9809
# Epoch 61, train-loss: 0.0619 - train_accuracy:0.9830 - val_loss:0.1396 -val_accuracy:0.9842
# Epoch 62, train-loss: 0.0605 - train_accuracy:0.9840 - val_loss:0.0792 -val_accuracy:0.9838
# Epoch 63, train-loss: 0.0609 - train_accuracy:0.9842 - val_loss:0.1055 -val_accuracy:0.9848
# Epoch 64, train-loss: 0.0572 - train_accuracy:0.9845 - val_loss:0.0823 -val_accuracy:0.9848
# Epoch 65, train-loss: 0.0560 - train_accuracy:0.9848 - val_loss:0.0962 -val_accuracy:0.9857
# Epoch 66, train-loss: 0.0541 - train_accuracy:0.9853 - val_loss:0.1196 -val_accuracy:0.9866
# Epoch 67, train-loss: 0.0522 - train_accuracy:0.9857 - val_loss:0.1035 -val_accuracy:0.9872
# Epoch 68, train-loss: 0.0513 - train_accuracy:0.9861 - val_loss:0.1390 -val_accuracy:0.9864
# Epoch 69, train-loss: 0.0512 - train_accuracy:0.9863 - val_loss:0.0980 -val_accuracy:0.9865
# Epoch 70, train-loss: 0.0490 - train_accuracy:0.9861 - val_loss:0.1848 -val_accuracy:0.9730
# Epoch 71, train-loss: 0.0530 - train_accuracy:0.9867 - val_loss:0.0726 -val_accuracy:0.9826
# Epoch 72, train-loss: 0.0606 - train_accuracy:0.9847 - val_loss:0.0537 -val_accuracy:0.9874
# Epoch 73, train-loss: 0.0499 - train_accuracy:0.9853 - val_loss:0.3481 -val_accuracy:0.7545
# Epoch 74, train-loss: 0.0593 - train_accuracy:0.9853 - val_loss:0.0753 -val_accuracy:0.9741
# Epoch 75, train-loss: 0.0816 - train_accuracy:0.9828 - val_loss:0.0519 -val_accuracy:0.9854
# Epoch 76, train-loss: 0.0633 - train_accuracy:0.9824 - val_loss:0.1355 -val_accuracy:0.9767
# Epoch 77, train-loss: 0.0577 - train_accuracy:0.9831 - val_loss:0.0785 -val_accuracy:0.9880
# Epoch 78, train-loss: 0.0520 - train_accuracy:0.9852 - val_loss:0.1194 -val_accuracy:0.9861
# Epoch 79, train-loss: 0.0502 - train_accuracy:0.9867 - val_loss:0.0842 -val_accuracy:0.9857
# Epoch 80, train-loss: 0.0511 - train_accuracy:0.9866 - val_loss:0.0840 -val_accuracy:0.9845
# Epoch 81, train-loss: 0.0466 - train_accuracy:0.9865 - val_loss:0.1524 -val_accuracy:0.9805
# Epoch 82, train-loss: 0.0467 - train_accuracy:0.9876 - val_loss:0.0768 -val_accuracy:0.9899
# Epoch 83, train-loss: 0.0435 - train_accuracy:0.9880 - val_loss:0.0595 -val_accuracy:0.9884
# Epoch 84, train-loss: 0.0423 - train_accuracy:0.9871 - val_loss:0.0494 -val_accuracy:0.9909
# Epoch 85, train-loss: 0.0394 - train_accuracy:0.9887 - val_loss:0.0646 -val_accuracy:0.9913
# Epoch 86, train-loss: 0.0371 - train_accuracy:0.9896 - val_loss:0.1075 -val_accuracy:0.9874
# Epoch 87, train-loss: 0.0371 - train_accuracy:0.9901 - val_loss:0.1660 -val_accuracy:0.9464
# Epoch 88, train-loss: 0.0353 - train_accuracy:0.9904 - val_loss:0.0685 -val_accuracy:0.9905
# Epoch 89, train-loss: 0.0388 - train_accuracy:0.9891 - val_loss:0.0850 -val_accuracy:0.9865
# Epoch 90, train-loss: 0.0363 - train_accuracy:0.9899 - val_loss:0.2054 -val_accuracy:0.8770
# Epoch 91, train-loss: 0.0353 - train_accuracy:0.9905 - val_loss:0.3488 -val_accuracy:0.7585
# Epoch 92, train-loss: 0.0402 - train_accuracy:0.9895 - val_loss:0.0406 -val_accuracy:0.9880
# Epoch 93, train-loss: 0.0493 - train_accuracy:0.9845 - val_loss:0.0514 -val_accuracy:0.9828
# Epoch 94, train-loss: 0.0608 - train_accuracy:0.9841 - val_loss:0.0580 -val_accuracy:0.9850
# Epoch 95, train-loss: 0.0790 - train_accuracy:0.9811 - val_loss:0.0452 -val_accuracy:0.9883
# Epoch 96, train-loss: 0.0679 - train_accuracy:0.9853 - val_loss:0.0497 -val_accuracy:0.9880
# Epoch 97, train-loss: 0.0500 - train_accuracy:0.9880 - val_loss:0.4454 -val_accuracy:0.7230
# Epoch 98, train-loss: 0.0740 - train_accuracy:0.9758 - val_loss:0.0554 -val_accuracy:0.9866
# Epoch 99, train-loss: 0.1036 - train_accuracy:0.9827 - val_loss:0.0938 -val_accuracy:0.9819
# Epoch 100, train-loss: 0.0951 - train_accuracy:0.9813 - val_loss:0.0546 -val_accuracy:0.9820
# Epoch 101, train-loss: 0.0641 - train_accuracy:0.9802 - val_loss:0.1595 -val_accuracy:0.9701
# Epoch 102, train-loss: 0.0725 - train_accuracy:0.9791 - val_loss:0.0624 -val_accuracy:0.9807
# Epoch 103, train-loss: 0.0686 - train_accuracy:0.9791 - val_loss:0.0607 -val_accuracy:0.9806
# Epoch 104, train-loss: 0.0598 - train_accuracy:0.9814 - val_loss:0.0665 -val_accuracy:0.9801
# Epoch 105, train-loss: 0.0555 - train_accuracy:0.9819 - val_loss:0.0528 -val_accuracy:0.9833
# Epoch 106, train-loss: 0.0520 - train_accuracy:0.9830 - val_loss:0.0678 -val_accuracy:0.9823
# Epoch 107, train-loss: 0.0499 - train_accuracy:0.9833 - val_loss:0.0468 -val_accuracy:0.9861
# Epoch 108, train-loss: 0.0465 - train_accuracy:0.9860 - val_loss:0.0584 -val_accuracy:0.9870
# Epoch 109, train-loss: 0.0431 - train_accuracy:0.9871 - val_loss:0.0545 -val_accuracy:0.9899
# Epoch 110, train-loss: 0.0404 - train_accuracy:0.9885 - val_loss:0.0544 -val_accuracy:0.9910
# Epoch 111, train-loss: 0.0399 - train_accuracy:0.9893 - val_loss:0.0521 -val_accuracy:0.9913
# Epoch 112, train-loss: 0.0394 - train_accuracy:0.9896 - val_loss:0.0549 -val_accuracy:0.9915
# Epoch 113, train-loss: 0.0372 - train_accuracy:0.9898 - val_loss:0.0482 -val_accuracy:0.9919
# Epoch 114, train-loss: 0.0360 - train_accuracy:0.9902 - val_loss:0.0430 -val_accuracy:0.9924
# Epoch 115, train-loss: 0.0347 - train_accuracy:0.9905 - val_loss:0.0397 -val_accuracy:0.9924
# Epoch 116, train-loss: 0.0336 - train_accuracy:0.9902 - val_loss:0.0402 -val_accuracy:0.9923
# Epoch 117, train-loss: 0.0321 - train_accuracy:0.9909 - val_loss:0.0383 -val_accuracy:0.9925
# Epoch 118, train-loss: 0.0318 - train_accuracy:0.9914 - val_loss:0.0470 -val_accuracy:0.9923
# Epoch 119, train-loss: 0.0327 - train_accuracy:0.9903 - val_loss:0.0396 -val_accuracy:0.9929
# Epoch 120, train-loss: 0.0313 - train_accuracy:0.9915 - val_loss:0.0556 -val_accuracy:0.9926
# Epoch 121, train-loss: 0.0299 - train_accuracy:0.9915 - val_loss:0.0631 -val_accuracy:0.9924
# Epoch 122, train-loss: 0.0297 - train_accuracy:0.9918 - val_loss:0.0606 -val_accuracy:0.9924
# Epoch 123, train-loss: 0.0276 - train_accuracy:0.9918 - val_loss:0.0767 -val_accuracy:0.9909
# Epoch 124, train-loss: 0.0270 - train_accuracy:0.9919 - val_loss:0.0707 -val_accuracy:0.9918
# Epoch 125, train-loss: 0.0268 - train_accuracy:0.9925 - val_loss:0.0875 -val_accuracy:0.9891
# Epoch 126, train-loss: 0.0256 - train_accuracy:0.9926 - val_loss:0.0981 -val_accuracy:0.9848
# Epoch 127, train-loss: 0.0252 - train_accuracy:0.9929 - val_loss:0.1027 -val_accuracy:0.9816
# Epoch 128, train-loss: 0.0248 - train_accuracy:0.9931 - val_loss:0.1200 -val_accuracy:0.9708
# Epoch 129, train-loss: 0.0249 - train_accuracy:0.9928 - val_loss:0.1389 -val_accuracy:0.9526
# Epoch 130, train-loss: 0.0247 - train_accuracy:0.9925 - val_loss:0.1117 -val_accuracy:0.9732
# Epoch 131, train-loss: 0.0252 - train_accuracy:0.9931 - val_loss:0.1674 -val_accuracy:0.9185
# Epoch 132, train-loss: 0.0258 - train_accuracy:0.9928 - val_loss:0.1434 -val_accuracy:0.9461
# Epoch 133, train-loss: 0.0239 - train_accuracy:0.9927 - val_loss:0.1310 -val_accuracy:0.9566
# Epoch 134, train-loss: 0.0231 - train_accuracy:0.9931 - val_loss:0.1214 -val_accuracy:0.9647
# Epoch 135, train-loss: 0.0243 - train_accuracy:0.9928 - val_loss:0.1626 -val_accuracy:0.9210
# Epoch 136, train-loss: 0.0240 - train_accuracy:0.9929 - val_loss:0.1604 -val_accuracy:0.9224
# Epoch 137, train-loss: 0.0236 - train_accuracy:0.9929 - val_loss:0.1754 -val_accuracy:0.9037
# Epoch 138, train-loss: 0.0232 - train_accuracy:0.9932 - val_loss:0.1429 -val_accuracy:0.9405
# Epoch 139, train-loss: 0.0220 - train_accuracy:0.9935 - val_loss:0.1649 -val_accuracy:0.9152
# Epoch 140, train-loss: 0.0222 - train_accuracy:0.9933 - val_loss:0.1330 -val_accuracy:0.9479
# Epoch 141, train-loss: 0.0228 - train_accuracy:0.9934 - val_loss:0.1839 -val_accuracy:0.8914
# Epoch 142, train-loss: 0.0218 - train_accuracy:0.9937 - val_loss:0.1283 -val_accuracy:0.9512
# Epoch 143, train-loss: 0.0215 - train_accuracy:0.9937 - val_loss:0.1391 -val_accuracy:0.9404
# Epoch 144, train-loss: 0.0212 - train_accuracy:0.9937 - val_loss:0.1662 -val_accuracy:0.9115
# Epoch 145, train-loss: 0.0207 - train_accuracy:0.9940 - val_loss:0.1516 -val_accuracy:0.9266
# Epoch 146, train-loss: 0.0213 - train_accuracy:0.9938 - val_loss:0.1316 -val_accuracy:0.9453
# Epoch 147, train-loss: 0.0213 - train_accuracy:0.9934 - val_loss:0.1464 -val_accuracy:0.9311
# Epoch 148, train-loss: 0.0212 - train_accuracy:0.9937 - val_loss:0.1860 -val_accuracy:0.8882
# Epoch 149, train-loss: 0.0209 - train_accuracy:0.9938 - val_loss:0.1434 -val_accuracy:0.9328
# Epoch 150, train-loss: 0.0211 - train_accuracy:0.9938 - val_loss:0.1748 -val_accuracy:0.8996
# Epoch 151, train-loss: 0.0215 - train_accuracy:0.9933 - val_loss:0.1481 -val_accuracy:0.9282
# Epoch 152, train-loss: 0.0225 - train_accuracy:0.9933 - val_loss:0.1660 -val_accuracy:0.9084
# Epoch 153, train-loss: 0.0229 - train_accuracy:0.9925 - val_loss:0.1772 -val_accuracy:0.8969
# Epoch 154, train-loss: 0.0202 - train_accuracy:0.9940 - val_loss:0.1423 -val_accuracy:0.9338
# Epoch 155, train-loss: 0.0197 - train_accuracy:0.9940 - val_loss:0.1373 -val_accuracy:0.9371
# Epoch 156, train-loss: 0.0194 - train_accuracy:0.9941 - val_loss:0.1140 -val_accuracy:0.9564
# Epoch 157, train-loss: 0.0195 - train_accuracy:0.9943 - val_loss:0.1356 -val_accuracy:0.9380
# Epoch 158, train-loss: 0.0192 - train_accuracy:0.9944 - val_loss:0.1319 -val_accuracy:0.9401
# Epoch 159, train-loss: 0.0190 - train_accuracy:0.9944 - val_loss:0.1424 -val_accuracy:0.9292
# Epoch 160, train-loss: 0.0191 - train_accuracy:0.9943 - val_loss:0.1622 -val_accuracy:0.9088
# Epoch 161, train-loss: 0.0190 - train_accuracy:0.9944 - val_loss:0.1473 -val_accuracy:0.9230
# Epoch 162, train-loss: 0.0192 - train_accuracy:0.9943 - val_loss:0.1394 -val_accuracy:0.9307
# Epoch 163, train-loss: 0.0188 - train_accuracy:0.9943 - val_loss:0.1310 -val_accuracy:0.9389
# Epoch 164, train-loss: 0.0184 - train_accuracy:0.9945 - val_loss:0.1487 -val_accuracy:0.9230
# Epoch 165, train-loss: 0.0183 - train_accuracy:0.9945 - val_loss:0.1400 -val_accuracy:0.9307
# Epoch 166, train-loss: 0.0181 - train_accuracy:0.9946 - val_loss:0.1530 -val_accuracy:0.9188
# Epoch 167, train-loss: 0.0178 - train_accuracy:0.9947 - val_loss:0.1313 -val_accuracy:0.9375
# Epoch 168, train-loss: 0.0184 - train_accuracy:0.9944 - val_loss:0.1371 -val_accuracy:0.9310
# Epoch 169, train-loss: 0.0194 - train_accuracy:0.9941 - val_loss:0.1900 -val_accuracy:0.8819
# Epoch 170, train-loss: 0.0188 - train_accuracy:0.9940 - val_loss:0.1505 -val_accuracy:0.9167
# Epoch 171, train-loss: 0.0192 - train_accuracy:0.9942 - val_loss:0.1854 -val_accuracy:0.8835
# Epoch 172, train-loss: 0.0180 - train_accuracy:0.9942 - val_loss:0.1249 -val_accuracy:0.9408
# Epoch 173, train-loss: 0.0181 - train_accuracy:0.9943 - val_loss:0.1491 -val_accuracy:0.9182
# Epoch 174, train-loss: 0.0182 - train_accuracy:0.9940 - val_loss:0.1571 -val_accuracy:0.9095
# Epoch 175, train-loss: 0.0181 - train_accuracy:0.9944 - val_loss:0.1425 -val_accuracy:0.9248
# Epoch 176, train-loss: 0.0183 - train_accuracy:0.9943 - val_loss:0.1250 -val_accuracy:0.9385
# Early stopping after epoch 176
# Finished Training

# %%
# plot loss and accuracy
plot_history(history_w_ea)

# %%
# evaluate and plot predicted results
predictions, accuracy = predict(net, test_loader)
predictions = np.stack(predictions, axis=0)
print('Accuracy: {:.3f}'.format(accuracy))
show_predictions(x_test, y_test, predictions)
# Out:
# Accuracy: 0.994

# %% [markdown]
# ### A3: Use a data generator to avoid overfitting

# %%
# As we have simulated data, we can use unlimited number of training examples
# image generator copied from https://github.com/jakeret/tf_unet
import image_gen

# %%
# define image shape
nx = 512
ny = 512

# create a wrapper generator 
def train_generator(batch_size):
    
    # init image generator with the following parameters:
    # nx, ny, cnt = 10, r_min = 5, r_max = 50, border = 92, sigma = 20, limit_num_samples = -1, binary = True
    #generator = image_gen.GrayScaleDataProvider(nx, ny, cnt=20, r_min=10, r_max=25, binary=True)
    data_generator = image_gen.GrayScaleDataProvider(nx, ny, cnt=20, r_min=10, r_max=25, binary=True)
   # batch_labels = np.zeros((batch_size, 1)) 
    while True:
        data, labels = data_generator(batch_size)
        data=torch.tensor(data).type(torch.FloatTensor)
        labels=torch.tensor(labels)
        yield data, labels

# %%
# define model
out_channels = 1
d_factors = [[2,2],[2,2],[2,2],[2,2]]
activation = torch.nn.Sigmoid()
early_stopping = EarlyStopping(patience=60)

net = torch.nn.Sequential(
    UNet(in_channels=1,
    num_fmaps=6,
    fmap_inc_factors=2,
    downsample_factors=d_factors,
    activation='ReLU',
    padding='same',
    num_fmaps_out=6,
    constant_upsample=False
    ),
    torch.nn.Conv2d(in_channels=6, out_channels=out_channels, kernel_size=1, padding=0, bias=True))

# %%
# train model
epochs = 200
net, history_w_gen,_ = train(net, epochs, learning_rate=8e-3, early_stopping=early_stopping,img_gen=iter(train_generator(4)))
print('Finished Training')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 1, train-loss: 0.7523 - train_accuracy:0.0670 - val_loss:0.7313 -val_accuracy:0.0706
# Epoch 2, train-loss: 0.7315 - train_accuracy:0.0689 - val_loss:0.7046 -val_accuracy:0.0706
# Epoch 3, train-loss: 0.7048 - train_accuracy:0.0661 - val_loss:0.6214 -val_accuracy:0.9293
# Epoch 4, train-loss: 0.6214 - train_accuracy:0.9299 - val_loss:1.7436 -val_accuracy:0.9294
# Epoch 5, train-loss: 1.7861 - train_accuracy:0.9277 - val_loss:0.5451 -val_accuracy:0.9294
# Epoch 6, train-loss: 0.5441 - train_accuracy:0.9323 - val_loss:0.6256 -val_accuracy:0.9294
# Epoch 7, train-loss: 0.6249 - train_accuracy:0.9344 - val_loss:0.6340 -val_accuracy:0.9294
# Epoch 8, train-loss: 0.6343 - train_accuracy:0.9279 - val_loss:0.6317 -val_accuracy:0.9294
# Epoch 9, train-loss: 0.6313 - train_accuracy:0.9328 - val_loss:0.6242 -val_accuracy:0.9294
# Epoch 10, train-loss: 0.6235 - train_accuracy:0.9345 - val_loss:0.6089 -val_accuracy:0.9294
# Epoch 11, train-loss: 0.6087 - train_accuracy:0.9304 - val_loss:0.5688 -val_accuracy:0.9294
# Epoch 12, train-loss: 0.5700 - train_accuracy:0.9262 - val_loss:0.4351 -val_accuracy:0.9294
# Epoch 13, train-loss: 0.4337 - train_accuracy:0.9313 - val_loss:0.3260 -val_accuracy:0.9294
# Epoch 14, train-loss: 0.2950 - train_accuracy:0.9369 - val_loss:0.3035 -val_accuracy:0.9294
# Epoch 15, train-loss: 0.2891 - train_accuracy:0.9334 - val_loss:0.3357 -val_accuracy:0.9294
# Epoch 16, train-loss: 0.3341 - train_accuracy:0.9307 - val_loss:0.3006 -val_accuracy:0.9294
# Epoch 17, train-loss: 0.2981 - train_accuracy:0.9307 - val_loss:0.3743 -val_accuracy:0.9294
# Epoch 18, train-loss: 0.3580 - train_accuracy:0.9326 - val_loss:0.2937 -val_accuracy:0.9294
# Epoch 19, train-loss: 0.2882 - train_accuracy:0.9321 - val_loss:0.3226 -val_accuracy:0.9294
# Epoch 20, train-loss: 0.3239 - train_accuracy:0.9287 - val_loss:0.2909 -val_accuracy:0.9294
# Epoch 21, train-loss: 0.2824 - train_accuracy:0.9336 - val_loss:0.2968 -val_accuracy:0.9294
# Epoch 22, train-loss: 0.2908 - train_accuracy:0.9310 - val_loss:0.3082 -val_accuracy:0.9294
# Epoch 23, train-loss: 0.2886 - train_accuracy:0.9346 - val_loss:0.2764 -val_accuracy:0.9294
# Epoch 24, train-loss: 0.2646 - train_accuracy:0.9339 - val_loss:0.2875 -val_accuracy:0.9294
# Epoch 25, train-loss: 0.2927 - train_accuracy:0.9268 - val_loss:0.2905 -val_accuracy:0.9294
# Epoch 26, train-loss: 0.3000 - train_accuracy:0.9244 - val_loss:0.2776 -val_accuracy:0.9294
# Epoch 27, train-loss: 0.2703 - train_accuracy:0.9327 - val_loss:0.2744 -val_accuracy:0.9294
# Epoch 28, train-loss: 0.2764 - train_accuracy:0.9287 - val_loss:0.2827 -val_accuracy:0.9294
# Epoch 29, train-loss: 0.2918 - train_accuracy:0.9266 - val_loss:0.2694 -val_accuracy:0.9294
# Epoch 30, train-loss: 0.2278 - train_accuracy:0.9442 - val_loss:0.2655 -val_accuracy:0.9294
# Epoch 31, train-loss: 0.2523 - train_accuracy:0.9346 - val_loss:0.2640 -val_accuracy:0.9294
# Epoch 32, train-loss: 0.2670 - train_accuracy:0.9279 - val_loss:0.2604 -val_accuracy:0.9294
# Epoch 33, train-loss: 0.2507 - train_accuracy:0.9330 - val_loss:0.2565 -val_accuracy:0.9294
# Epoch 34, train-loss: 0.2412 - train_accuracy:0.9349 - val_loss:0.2555 -val_accuracy:0.9294
# Epoch 35, train-loss: 0.2417 - train_accuracy:0.9346 - val_loss:0.2487 -val_accuracy:0.9294
# Epoch 36, train-loss: 0.2262 - train_accuracy:0.9380 - val_loss:0.2422 -val_accuracy:0.9294
# Epoch 37, train-loss: 0.2325 - train_accuracy:0.9334 - val_loss:0.2348 -val_accuracy:0.9294
# Epoch 38, train-loss: 0.2139 - train_accuracy:0.9372 - val_loss:0.2658 -val_accuracy:0.9294
# Epoch 39, train-loss: 0.2552 - train_accuracy:0.9322 - val_loss:0.2382 -val_accuracy:0.9294
# Epoch 40, train-loss: 0.2337 - train_accuracy:0.9294 - val_loss:0.2411 -val_accuracy:0.9294
# Epoch 41, train-loss: 0.2328 - train_accuracy:0.9294 - val_loss:0.2280 -val_accuracy:0.9294
# Epoch 42, train-loss: 0.2273 - train_accuracy:0.9292 - val_loss:0.2073 -val_accuracy:0.9294
# Epoch 43, train-loss: 0.1917 - train_accuracy:0.9346 - val_loss:0.1951 -val_accuracy:0.9294
# Epoch 44, train-loss: 0.1887 - train_accuracy:0.9309 - val_loss:0.1923 -val_accuracy:0.9294
# Epoch 45, train-loss: 0.1845 - train_accuracy:0.9300 - val_loss:0.1863 -val_accuracy:0.9294
# Epoch 46, train-loss: 0.1813 - train_accuracy:0.9326 - val_loss:0.1807 -val_accuracy:0.9294
# Epoch 47, train-loss: 0.1524 - train_accuracy:0.9379 - val_loss:0.1734 -val_accuracy:0.9294
# Epoch 48, train-loss: 0.1712 - train_accuracy:0.9324 - val_loss:0.1637 -val_accuracy:0.9294
# Epoch 49, train-loss: 0.1540 - train_accuracy:0.9337 - val_loss:0.1549 -val_accuracy:0.9294
# Epoch 50, train-loss: 0.1489 - train_accuracy:0.9317 - val_loss:0.1491 -val_accuracy:0.9294
# Epoch 51, train-loss: 0.1501 - train_accuracy:0.9279 - val_loss:0.1453 -val_accuracy:0.9294
# Epoch 52, train-loss: 0.1399 - train_accuracy:0.9274 - val_loss:0.1445 -val_accuracy:0.9294
# Epoch 53, train-loss: 0.1388 - train_accuracy:0.9359 - val_loss:0.1415 -val_accuracy:0.9294
# Epoch 54, train-loss: 0.1187 - train_accuracy:0.9350 - val_loss:0.1247 -val_accuracy:0.9294
# Epoch 55, train-loss: 0.0962 - train_accuracy:0.9396 - val_loss:0.1104 -val_accuracy:0.9294
# Epoch 56, train-loss: 0.1020 - train_accuracy:0.9350 - val_loss:0.1034 -val_accuracy:0.9294
# Epoch 57, train-loss: 0.0918 - train_accuracy:0.9297 - val_loss:0.0985 -val_accuracy:0.9294
# Epoch 58, train-loss: 0.0815 - train_accuracy:0.9304 - val_loss:0.1054 -val_accuracy:0.9294
# Epoch 59, train-loss: 0.1100 - train_accuracy:0.9278 - val_loss:0.0859 -val_accuracy:0.9294
# Epoch 60, train-loss: 0.0872 - train_accuracy:0.9286 - val_loss:0.0930 -val_accuracy:0.9294
# Epoch 61, train-loss: 0.0830 - train_accuracy:0.9319 - val_loss:0.0832 -val_accuracy:0.9294
# Epoch 62, train-loss: 0.0905 - train_accuracy:0.9298 - val_loss:0.0823 -val_accuracy:0.9294
# Epoch 63, train-loss: 0.0876 - train_accuracy:0.9277 - val_loss:0.1235 -val_accuracy:0.9294
# Epoch 64, train-loss: 0.0766 - train_accuracy:0.9283 - val_loss:0.2086 -val_accuracy:0.9781
# Epoch 65, train-loss: 0.0842 - train_accuracy:0.9861 - val_loss:0.0809 -val_accuracy:0.9804
# Epoch 66, train-loss: 0.0903 - train_accuracy:0.9786 - val_loss:0.0714 -val_accuracy:0.9834
# Epoch 67, train-loss: 0.1175 - train_accuracy:0.9789 - val_loss:0.0562 -val_accuracy:0.9902
# Epoch 68, train-loss: 0.0824 - train_accuracy:0.9825 - val_loss:0.4416 -val_accuracy:0.7530
# Epoch 69, train-loss: 0.1525 - train_accuracy:0.9517 - val_loss:0.0766 -val_accuracy:0.9817
# Epoch 70, train-loss: 0.1216 - train_accuracy:0.9771 - val_loss:0.1118 -val_accuracy:0.9680
# Epoch 71, train-loss: 0.1459 - train_accuracy:0.9659 - val_loss:0.1211 -val_accuracy:0.9678
# Epoch 72, train-loss: 0.1754 - train_accuracy:0.9682 - val_loss:0.1056 -val_accuracy:0.9701
# Epoch 73, train-loss: 0.1366 - train_accuracy:0.9709 - val_loss:0.0829 -val_accuracy:0.9734
# Epoch 74, train-loss: 0.1118 - train_accuracy:0.9718 - val_loss:0.0765 -val_accuracy:0.9786
# Epoch 75, train-loss: 0.0812 - train_accuracy:0.9757 - val_loss:0.1416 -val_accuracy:0.9846
# Epoch 76, train-loss: 0.1296 - train_accuracy:0.9811 - val_loss:0.1165 -val_accuracy:0.9857
# Epoch 77, train-loss: 0.0983 - train_accuracy:0.9804 - val_loss:0.0861 -val_accuracy:0.9861
# Epoch 78, train-loss: 0.0745 - train_accuracy:0.9827 - val_loss:0.0675 -val_accuracy:0.9864
# Epoch 79, train-loss: 0.0646 - train_accuracy:0.9847 - val_loss:0.0577 -val_accuracy:0.9868
# Epoch 80, train-loss: 0.0601 - train_accuracy:0.9839 - val_loss:0.0519 -val_accuracy:0.9875
# Epoch 81, train-loss: 0.0530 - train_accuracy:0.9855 - val_loss:0.0478 -val_accuracy:0.9882
# Epoch 82, train-loss: 0.0471 - train_accuracy:0.9882 - val_loss:0.0451 -val_accuracy:0.9888
# Epoch 83, train-loss: 0.0428 - train_accuracy:0.9872 - val_loss:0.0458 -val_accuracy:0.9893
# Epoch 84, train-loss: 0.0415 - train_accuracy:0.9890 - val_loss:0.0545 -val_accuracy:0.9895
# Epoch 85, train-loss: 0.0527 - train_accuracy:0.9861 - val_loss:0.0746 -val_accuracy:0.9891
# Epoch 86, train-loss: 0.0473 - train_accuracy:0.9854 - val_loss:0.0985 -val_accuracy:0.9884
# Epoch 87, train-loss: 0.0720 - train_accuracy:0.9815 - val_loss:0.1199 -val_accuracy:0.9873
# Epoch 88, train-loss: 0.0608 - train_accuracy:0.9842 - val_loss:0.1250 -val_accuracy:0.9862
# Epoch 89, train-loss: 0.0497 - train_accuracy:0.9842 - val_loss:0.1322 -val_accuracy:0.9845
# Epoch 90, train-loss: 0.0870 - train_accuracy:0.9841 - val_loss:0.0777 -val_accuracy:0.9879
# Epoch 91, train-loss: 0.0543 - train_accuracy:0.9846 - val_loss:0.0555 -val_accuracy:0.9887
# Epoch 92, train-loss: 0.0370 - train_accuracy:0.9896 - val_loss:0.0449 -val_accuracy:0.9892
# Epoch 93, train-loss: 0.0478 - train_accuracy:0.9870 - val_loss:0.0411 -val_accuracy:0.9895
# Epoch 94, train-loss: 0.0420 - train_accuracy:0.9880 - val_loss:0.0402 -val_accuracy:0.9896
# Epoch 95, train-loss: 0.0716 - train_accuracy:0.9865 - val_loss:0.0429 -val_accuracy:0.9896
# Epoch 96, train-loss: 0.1065 - train_accuracy:0.9824 - val_loss:0.0803 -val_accuracy:0.9879
# Epoch 97, train-loss: 0.0841 - train_accuracy:0.9855 - val_loss:0.0444 -val_accuracy:0.9898
# Epoch 98, train-loss: 0.0475 - train_accuracy:0.9896 - val_loss:0.0432 -val_accuracy:0.9900
# Epoch 99, train-loss: 0.0323 - train_accuracy:0.9881 - val_loss:0.0443 -val_accuracy:0.9901
# Epoch 100, train-loss: 0.0241 - train_accuracy:0.9928 - val_loss:0.0455 -val_accuracy:0.9902
# Epoch 101, train-loss: 0.0411 - train_accuracy:0.9887 - val_loss:0.0488 -val_accuracy:0.9903
# Epoch 102, train-loss: 0.0404 - train_accuracy:0.9903 - val_loss:0.0527 -val_accuracy:0.9904
# Epoch 103, train-loss: 0.0452 - train_accuracy:0.9862 - val_loss:0.0624 -val_accuracy:0.9905
# Epoch 104, train-loss: 0.0415 - train_accuracy:0.9889 - val_loss:0.0695 -val_accuracy:0.9906
# Epoch 105, train-loss: 0.0294 - train_accuracy:0.9908 - val_loss:0.0790 -val_accuracy:0.9906
# Epoch 106, train-loss: 0.0719 - train_accuracy:0.9885 - val_loss:0.0627 -val_accuracy:0.9907
# Epoch 107, train-loss: 0.0318 - train_accuracy:0.9909 - val_loss:0.0518 -val_accuracy:0.9906
# Epoch 108, train-loss: 0.0421 - train_accuracy:0.9888 - val_loss:0.0436 -val_accuracy:0.9903
# Epoch 109, train-loss: 0.0423 - train_accuracy:0.9846 - val_loss:0.0406 -val_accuracy:0.9897
# Epoch 110, train-loss: 0.0450 - train_accuracy:0.9886 - val_loss:0.0475 -val_accuracy:0.9832
# Epoch 111, train-loss: 0.0409 - train_accuracy:0.9868 - val_loss:0.0436 -val_accuracy:0.9905
# Epoch 112, train-loss: 0.0658 - train_accuracy:0.9838 - val_loss:0.0501 -val_accuracy:0.9906
# Epoch 113, train-loss: 0.0304 - train_accuracy:0.9915 - val_loss:0.0580 -val_accuracy:0.9906
# Epoch 114, train-loss: 0.0435 - train_accuracy:0.9888 - val_loss:0.0710 -val_accuracy:0.9903
# Epoch 115, train-loss: 0.0311 - train_accuracy:0.9900 - val_loss:0.0802 -val_accuracy:0.9900
# Epoch 116, train-loss: 0.0371 - train_accuracy:0.9904 - val_loss:0.0796 -val_accuracy:0.9899
# Epoch 117, train-loss: 0.0498 - train_accuracy:0.9890 - val_loss:0.0760 -val_accuracy:0.9900
# Epoch 118, train-loss: 0.0295 - train_accuracy:0.9895 - val_loss:0.0708 -val_accuracy:0.9901
# Epoch 119, train-loss: 0.0302 - train_accuracy:0.9909 - val_loss:0.0645 -val_accuracy:0.9902
# Epoch 120, train-loss: 0.0455 - train_accuracy:0.9897 - val_loss:0.0536 -val_accuracy:0.9905
# Epoch 121, train-loss: 0.0248 - train_accuracy:0.9929 - val_loss:0.0448 -val_accuracy:0.9907
# Epoch 122, train-loss: 0.0506 - train_accuracy:0.9889 - val_loss:0.0425 -val_accuracy:0.9908
# Epoch 123, train-loss: 0.0352 - train_accuracy:0.9880 - val_loss:0.0444 -val_accuracy:0.9909
# Epoch 124, train-loss: 0.0347 - train_accuracy:0.9919 - val_loss:0.0416 -val_accuracy:0.9909
# Epoch 125, train-loss: 0.0338 - train_accuracy:0.9904 - val_loss:0.0429 -val_accuracy:0.9910
# Epoch 126, train-loss: 0.0362 - train_accuracy:0.9932 - val_loss:0.0396 -val_accuracy:0.9910
# Epoch 127, train-loss: 0.0493 - train_accuracy:0.9890 - val_loss:0.0356 -val_accuracy:0.9908
# Epoch 128, train-loss: 0.0478 - train_accuracy:0.9877 - val_loss:0.0348 -val_accuracy:0.9907
# Epoch 129, train-loss: 0.0642 - train_accuracy:0.9859 - val_loss:0.0352 -val_accuracy:0.9908
# Epoch 130, train-loss: 0.0369 - train_accuracy:0.9895 - val_loss:0.0370 -val_accuracy:0.9909
# Epoch 131, train-loss: 0.0627 - train_accuracy:0.9840 - val_loss:0.0462 -val_accuracy:0.9910
# Epoch 132, train-loss: 0.0243 - train_accuracy:0.9910 - val_loss:0.0650 -val_accuracy:0.9906
# Epoch 133, train-loss: 0.0417 - train_accuracy:0.9889 - val_loss:0.0952 -val_accuracy:0.9893
# Epoch 134, train-loss: 0.0331 - train_accuracy:0.9914 - val_loss:0.1255 -val_accuracy:0.9860
# Epoch 135, train-loss: 0.0334 - train_accuracy:0.9921 - val_loss:0.1390 -val_accuracy:0.9834
# Epoch 136, train-loss: 0.2024 - train_accuracy:0.9169 - val_loss:0.0391 -val_accuracy:0.9910
# Epoch 137, train-loss: 0.0382 - train_accuracy:0.9897 - val_loss:0.0416 -val_accuracy:0.9874
# Epoch 138, train-loss: 0.0615 - train_accuracy:0.9817 - val_loss:0.0576 -val_accuracy:0.9823
# Epoch 139, train-loss: 0.0705 - train_accuracy:0.9827 - val_loss:0.0699 -val_accuracy:0.9779
# Epoch 140, train-loss: 0.0814 - train_accuracy:0.9800 - val_loss:0.0750 -val_accuracy:0.9760
# Epoch 141, train-loss: 0.0945 - train_accuracy:0.9726 - val_loss:0.0718 -val_accuracy:0.9761
# Epoch 142, train-loss: 0.0896 - train_accuracy:0.9765 - val_loss:0.0648 -val_accuracy:0.9771
# Epoch 143, train-loss: 0.0438 - train_accuracy:0.9859 - val_loss:0.0605 -val_accuracy:0.9782
# Epoch 144, train-loss: 0.0760 - train_accuracy:0.9760 - val_loss:0.0599 -val_accuracy:0.9795
# Epoch 145, train-loss: 0.0672 - train_accuracy:0.9788 - val_loss:0.0647 -val_accuracy:0.9811
# Epoch 146, train-loss: 0.0833 - train_accuracy:0.9732 - val_loss:0.0742 -val_accuracy:0.9829
# Epoch 147, train-loss: 0.0773 - train_accuracy:0.9828 - val_loss:0.0813 -val_accuracy:0.9843
# Epoch 148, train-loss: 0.0725 - train_accuracy:0.9864 - val_loss:0.0816 -val_accuracy:0.9851
# Epoch 149, train-loss: 0.0728 - train_accuracy:0.9832 - val_loss:0.0785 -val_accuracy:0.9856
# Epoch 150, train-loss: 0.0697 - train_accuracy:0.9844 - val_loss:0.0730 -val_accuracy:0.9859
# Epoch 151, train-loss: 0.0574 - train_accuracy:0.9858 - val_loss:0.0668 -val_accuracy:0.9861
# Epoch 152, train-loss: 0.0532 - train_accuracy:0.9905 - val_loss:0.0602 -val_accuracy:0.9860
# Epoch 153, train-loss: 0.0825 - train_accuracy:0.9754 - val_loss:0.0555 -val_accuracy:0.9861
# Epoch 154, train-loss: 0.0777 - train_accuracy:0.9774 - val_loss:0.0521 -val_accuracy:0.9865
# Epoch 155, train-loss: 0.0527 - train_accuracy:0.9856 - val_loss:0.0493 -val_accuracy:0.9869
# Epoch 156, train-loss: 0.0536 - train_accuracy:0.9859 - val_loss:0.0472 -val_accuracy:0.9874
# Epoch 157, train-loss: 0.0409 - train_accuracy:0.9884 - val_loss:0.0454 -val_accuracy:0.9878
# Epoch 158, train-loss: 0.0443 - train_accuracy:0.9867 - val_loss:0.0439 -val_accuracy:0.9883
# Epoch 159, train-loss: 0.0521 - train_accuracy:0.9850 - val_loss:0.0428 -val_accuracy:0.9888
# Epoch 160, train-loss: 0.0319 - train_accuracy:0.9903 - val_loss:0.0422 -val_accuracy:0.9892
# Epoch 161, train-loss: 0.0517 - train_accuracy:0.9871 - val_loss:0.0420 -val_accuracy:0.9895
# Epoch 162, train-loss: 0.0373 - train_accuracy:0.9892 - val_loss:0.0424 -val_accuracy:0.9898
# Epoch 163, train-loss: 0.0454 - train_accuracy:0.9869 - val_loss:0.0436 -val_accuracy:0.9900
# Epoch 164, train-loss: 0.0407 - train_accuracy:0.9859 - val_loss:0.0464 -val_accuracy:0.9901
# Epoch 165, train-loss: 0.0629 - train_accuracy:0.9809 - val_loss:0.0521 -val_accuracy:0.9901
# Epoch 166, train-loss: 0.0594 - train_accuracy:0.9844 - val_loss:0.0585 -val_accuracy:0.9900
# Epoch 167, train-loss: 0.0515 - train_accuracy:0.9871 - val_loss:0.0660 -val_accuracy:0.9899
# Epoch 168, train-loss: 0.0785 - train_accuracy:0.9890 - val_loss:0.0590 -val_accuracy:0.9901
# Epoch 169, train-loss: 0.0536 - train_accuracy:0.9870 - val_loss:0.0526 -val_accuracy:0.9902
# Epoch 170, train-loss: 0.0780 - train_accuracy:0.9865 - val_loss:0.0444 -val_accuracy:0.9904
# Epoch 171, train-loss: 0.0418 - train_accuracy:0.9885 - val_loss:0.0401 -val_accuracy:0.9904
# Epoch 172, train-loss: 0.0376 - train_accuracy:0.9918 - val_loss:0.0375 -val_accuracy:0.9903
# Epoch 173, train-loss: 0.0622 - train_accuracy:0.9840 - val_loss:0.0368 -val_accuracy:0.9902
# Epoch 174, train-loss: 0.0452 - train_accuracy:0.9887 - val_loss:0.0371 -val_accuracy:0.9898
# Epoch 175, train-loss: 0.0491 - train_accuracy:0.9875 - val_loss:0.0373 -val_accuracy:0.9897
# Epoch 176, train-loss: 0.0280 - train_accuracy:0.9910 - val_loss:0.0373 -val_accuracy:0.9897
# Epoch 177, train-loss: 0.0238 - train_accuracy:0.9923 - val_loss:0.0371 -val_accuracy:0.9898
# Epoch 178, train-loss: 0.0486 - train_accuracy:0.9871 - val_loss:0.0366 -val_accuracy:0.9900
# Epoch 179, train-loss: 0.0247 - train_accuracy:0.9932 - val_loss:0.0364 -val_accuracy:0.9902
# Epoch 180, train-loss: 0.0386 - train_accuracy:0.9907 - val_loss:0.0362 -val_accuracy:0.9903
# Epoch 181, train-loss: 0.0331 - train_accuracy:0.9893 - val_loss:0.0365 -val_accuracy:0.9904
# Epoch 182, train-loss: 0.0432 - train_accuracy:0.9869 - val_loss:0.0377 -val_accuracy:0.9906
# Epoch 183, train-loss: 0.0299 - train_accuracy:0.9924 - val_loss:0.0397 -val_accuracy:0.9907
# Epoch 184, train-loss: 0.0316 - train_accuracy:0.9913 - val_loss:0.0421 -val_accuracy:0.9907
# Epoch 185, train-loss: 0.0552 - train_accuracy:0.9841 - val_loss:0.0463 -val_accuracy:0.9908
# Epoch 186, train-loss: 0.0325 - train_accuracy:0.9910 - val_loss:0.0504 -val_accuracy:0.9908
# Epoch 187, train-loss: 0.0672 - train_accuracy:0.9836 - val_loss:0.0586 -val_accuracy:0.9907
# Early stopping after epoch 187
# Finished Training

# %%
# plot loss and accuracy
plot_history(history_w_gen)

# %%
# evaluate and plot predicted results
predictions, accuracy = predict(net, test_loader)
predictions = np.stack(predictions, axis=0)
print('Accuracy: {:.3f}'.format(accuracy))
show_predictions(x_test, y_test, predictions)
# Out:
# Accuracy: 0.990
